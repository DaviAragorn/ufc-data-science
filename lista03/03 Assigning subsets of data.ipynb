# %% [markdown]
# # Selecting Subsets of Data in Pandas
#
# This notebook is also available as a [blog post on Medium](https://medium.com/dunder-data/selecting-subsets-of-data-in-pandas-part-3-d5704b4b9116).
#
# ## Part 3: Assigning subsets of data
# This is part 3 of a 7-part series on how to select subsets of data from a pandas DataFrame or Series. Pandas offers a wide variety of options for subset selection which necessitates multiple articles. This series is broken down into the following 7 topics.
#
# 1. Selection with `[]`, `.loc` and `.iloc`
# 1. Boolean indexing
# 1. Assigning subsets of data
# 1. Selection with a MultiIndex
# 1. Selecting subsets of data with methods
# 1. Selections with other Index types
# 1. Internals, Miscellaneous, and Conclusion
#
# ## Assignment
# When you see the word **assign** used during a discussion on programming, it usually means that a variable is set equal to some value. For most programming languages, this means using the equal sign. For instance, to assign the value 5 to the variable **`x`** in Python, we do the following:
#
# ```Python
# x = 5
# ```
#
# This is formally called an [assignment statement][1]. More generally, we can define Python assignment statements as follows:
#
# ```Python
# variable = expression
# ```
#
# There is quite a bit more to the [Python assignment statement](https://docs.python.org/3/reference/simple_stmts.html), but for our purposes it just means using the equal sign to store the object on the right-hand side to the left-hand side.
#
# ## Documentation on Assigning subsets of data
# There isn't one particular sub-section of the documentation that covers this topic precisely. Several examples are available throughout the entire [indexing section](http://pandas.pydata.org/pandas-docs/stable/indexing.html).
#
# ## What does this have to do with selecting subsets of data?
# In this article, we will use the assignment statement, but only after we select a subset of data. We will be doing our subset selection based on what we learned from [part 1](https://medium.com/dunder-data/selecting-subsets-of-data-in-pandas-6fcd0170be9c) and [part 2](https://medium.com/dunder-data/selecting-subsets-of-data-in-pandas-39e811c81a0c) and changing just those values.
#
# The left-hand side will have our subset selection and the right-hand side will contain our new values like this:
#
# ```Python
# subset_of_DataFrame_or_Series = new_values
# ```
#
# ## Small Sample Dataset
# During this tutorial, we will be working with a small sample of the [employee](Dataset%20Descriptions.ipynb#Employee-Data) dataset. The small dataset will help us immediately see the changes. Let's take a look at this dataset now, which uses the index to store the names of each employee.
#
# [1]: https://en.wikipedia.org/wiki/Assignment_(computer_science)

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('./employee_sample.csv', index_col=0)
df
# cols = df_all.columns
# df = df_all[cols].head(5)
# df
# Out:
#           GENDER   RACE          DEPARTMENT  YEARS EXPERIENCE  SALARY
# Tom         Male  White         Engineering                23  107962
# Niko        Male  Black         Engineering                 1   30347
# Penelope  Female  White         Engineering                12   60258
# Aria      Female  Black         Engineering                 8   43618
# Sofia     Female  Black  Parks & Recreation                23   26125
# Dean        Male  Black  Parks & Recreation                 3   33592
# Zach        Male  White  Parks & Recreation                 4   37565

# %% [markdown]
# ## Creating a new column
# Before we change any of the data in this DataFrame, we will add a single column to the end. There are multiple ways of doing so, but we will begin by using *just the indexing operator* (the brackets). Place a string inside of the brackets and make this the left-hand side of the assignment.
#
# The right-hand side can consist of any of the following:
# * A scalar value
# * A list or array with the same length as the DataFrame
# * A pandas Series with an index that matches the index of the DataFrame (a little tricky!)
#
# ## New column assigned to a scalar value
# A **scalar** value is simply one single value, like an integer, string, boolean or date. When using a scalar for column assignment, each value in the column will be the same. Let's create a column **`SCORE`** and assign it the value 99.

# %%
df['SCORE'] = 99

# %% [markdown]
# ## Where's the output?
# In the previous two notebooks, we were only making column selections (no equal signs) resulting in output displayed directly into the notebook after executing the line of code. In the above, we made an assignment, which will not yield any output. We must use an extra line to display our data.

# %%
df
# Out:
#           GENDER   RACE          DEPARTMENT  YEARS EXPERIENCE  SALARY  SCORE
# Tom         Male  White         Engineering                23  107962     99
# Niko        Male  Black         Engineering                 1   30347     99
# Penelope  Female  White         Engineering                12   60258     99
# Aria      Female  Black         Engineering                 8   43618     99
# Sofia     Female  Black  Parks & Recreation                23   26125     99
# Dean        Male  Black  Parks & Recreation                 3   33592     99
# Zach        Male  White  Parks & Recreation                 4   37565     99

# %% [markdown]
# ## Create a new column with a list or array
#
# Instead of creating a new column with all the same values, we can use a list or NumPy array with different values for each row. The only stipulation is that the number of new values in the list/array must be the same as the number of rows in the DataFrame.
#
# Let's create the column **`BONUS RATE`**, with a list of numbers between 0 and 1.

# %%
df['BONUS RATE'] = [.2, .1, 0, .15, .12, .3, .05]
df
# Out:
#           GENDER   RACE          DEPARTMENT  YEARS EXPERIENCE  SALARY  SCORE  \
# Tom         Male  White         Engineering                23  107962     99
# Niko        Male  Black         Engineering                 1   30347     99
# Penelope  Female  White         Engineering                12   60258     99
# Aria      Female  Black         Engineering                 8   43618     99
# Sofia     Female  Black  Parks & Recreation                23   26125     99
# Dean        Male  Black  Parks & Recreation                 3   33592     99
# Zach        Male  White  Parks & Recreation                 4   37565     99
#
#           BONUS RATE
# Tom             0.20
# Niko            0.10
# Penelope        0.00
# Aria            0.15
# Sofia           0.12
# Dean            0.30
# Zach            0.05

# %% [markdown]
# We could have just as easily used a one dimensional NumPy array to get the same exact results. Let's do just that and create a random array of integers to represent the floor that the employee works on.
#
# We use the **`randint`** function from NumPy's **`rand`** module. Use the **`low`** (inclusive) and **`high`** (exclusive) parameters to bound the range of possible integers. **`len(df)`** returns the number of rows in the DataFrame ensuring that the size of the array is correct..

# %%
floor = np.random.randint(low=1, high=10, size=len(df))
floor
# Out:
# array([2, 1, 8, 6, 4, 7, 3])

# %% [markdown]
# Then assign this to the **`FLOOR`** column:

# %%
df['FLOOR'] = floor
df
# Out:
#           GENDER   RACE          DEPARTMENT  YEARS EXPERIENCE  SALARY  SCORE  \
# Tom         Male  White         Engineering                23  107962     99
# Niko        Male  Black         Engineering                 1   30347     99
# Penelope  Female  White         Engineering                12   60258     99
# Aria      Female  Black         Engineering                 8   43618     99
# Sofia     Female  Black  Parks & Recreation                23   26125     99
# Dean        Male  Black  Parks & Recreation                 3   33592     99
# Zach        Male  White  Parks & Recreation                 4   37565     99
#
#           BONUS RATE  FLOOR
# Tom             0.20      2
# Niko            0.10      1
# Penelope        0.00      8
# Aria            0.15      6
# Sofia           0.12      4
# Dean            0.30      7
# Zach            0.05      3

# %% [markdown]
# ## Creating a new column with a Series (tricky!)
# Let's create a new pandas Series and see what happens when we attempt to assign it as a new column in our DataFrame.
#
# Let's try and add a column for the last name of each person.

# %%
last_name = pd.Series(['Smith', 'Jones', 'Williams', 'Green', 'Brown', 'Simpson', 'Peters'])
last_name
# Out:
# 0       Smith
# 1       Jones
# 2    Williams
# 3       Green
# 4       Brown
# 5     Simpson
# 6      Peters
# dtype: object

# %% [markdown]
# Make the assignment like we have done above:

# %%
df['LAST NAME'] = last_name
df
# Out:
#           GENDER   RACE          DEPARTMENT  YEARS EXPERIENCE  SALARY  SCORE  \
# Tom         Male  White         Engineering                23  107962     99
# Niko        Male  Black         Engineering                 1   30347     99
# Penelope  Female  White         Engineering                12   60258     99
# Aria      Female  Black         Engineering                 8   43618     99
# Sofia     Female  Black  Parks & Recreation                23   26125     99
# Dean        Male  Black  Parks & Recreation                 3   33592     99
# Zach        Male  White  Parks & Recreation                 4   37565     99
#
#           BONUS RATE  FLOOR LAST NAME
# Tom             0.20      2       NaN
# Niko            0.10      1       NaN
# Penelope        0.00      8       NaN
# Aria            0.15      6       NaN
# Sofia           0.12      4       NaN
# Dean            0.30      7       NaN
# Zach            0.05      3       NaN

# %% [markdown]
# ## All missing values!
# Our attempt failed because pandas uses a completely different methodology for combining two pandas objects.
#
# ## Automatic alignment of the Index
# Whenever two pandas objects are combined in some fashion the row/column index of one is aligned with the row/column index of the other. This all happens silently and implicitly behind the scenes. So if you are unaware of it, you will be completely taken by surprise. I will dedicate several notebooks in a different section to this surprising yet powerful feature.
#
# Our operation failed to add the last names because the index of our Series is the integers 0 through 6, while the index of the DataFrame are the names of the employees. There are no index values in common between the objects, so pandas defaults to NaN (Not a number).
#
# ## Create a Series with same Index as DataFrame
# To use a Series to create a new column, the index must match that of the modifying DataFrame. Let's re-create our Series with the same index as the DataFrame.

# %%
last_name = p                                                                                             
last_name
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-58-64474dc45bdf> in <module>
# ----> 1 last_name = p
#       2 last_name
#
# NameError: name 'p' is not defined

# %% [markdown]
# Let's try that assignment again. This technically will overwrite our previous **`LAST NAME`** column

# %%
df['LAST NAME'] = last_name
df
# Out:
#           GENDER   RACE          DEPARTMENT  YEARS EXPERIENCE  SALARY  SCORE  \
# Tom         Male  White         Engineering                23  107962     99
# Niko        Male  Black         Engineering                 1   30347     99
# Penelope  Female  White         Engineering                12   60258     99
# Aria      Female  Black         Engineering                 8   43618     99
# Sofia     Female  Black  Parks & Recreation                23   26125     99
# Dean        Male  Black  Parks & Recreation                 3   33592     99
# Zach        Male  White  Parks & Recreation                 4   37565     99
#
#           BONUS RATE  FLOOR LAST NAME
# Tom             0.20      2       NaN
# Niko            0.10      1       NaN
# Penelope        0.00      8       NaN
# Aria            0.15      6       NaN
# Sofia           0.12      4       NaN
# Dean            0.30      7       NaN
# Zach            0.05      3       NaN

# %% [markdown]
# ## Create a new column with expressions involving other columns
# We can create a new column by combining any number of other columns. One primary way of doing that is through a mathematical expression. For instance, let's create a new column **`BONUS`** by multiplying the **`BONUS RATE`** and **`SALARY`** columns together.
#
# ## Output before assignment
# Before adding this new column to your DataFrame, you might want to consider viewing the output before making the assignment. This gives you a little preview so that you can check your work before doing the more permanent assignment.
#
# Let's multiple our two columns without assignment:

# %%
df['BONUS RATE'] * df['SALARY']
# Out:
# Tom         21592.40
# Niko         3034.70
# Penelope        0.00
# Aria         6542.70
# Sofia        3135.00
# Dean        10077.60
# Zach         1878.25
# dtype: float64

# %% [markdown]
# Everything appears to be OK, so go ahead and make the assignment. Notice that the output is a Series with index the same as the DataFrame.

# %%
df['BONUS'] = df['BONUS RATE'] * df['SALARY']
df
# Out:
#           GENDER   RACE          DEPARTMENT  YEARS EXPERIENCE  SALARY  SCORE  \
# Tom         Male  White         Engineering                23  107962     99
# Niko        Male  Black         Engineering                 1   30347     99
# Penelope  Female  White         Engineering                12   60258     99
# Aria      Female  Black         Engineering                 8   43618     99
# Sofia     Female  Black  Parks & Recreation                23   26125     99
# Dean        Male  Black  Parks & Recreation                 3   33592     99
# Zach        Male  White  Parks & Recreation                 4   37565     99
#
#           BONUS RATE  FLOOR LAST NAME     BONUS
# Tom             0.20      2       NaN  21592.40
# Niko            0.10      1       NaN   3034.70
# Penelope        0.00      8       NaN      0.00
# Aria            0.15      6       NaN   6542.70
# Sofia           0.12      4       NaN   3135.00
# Dean            0.30      7       NaN  10077.60
# Zach            0.05      3       NaN   1878.25

# %% [markdown]
# # Actual Subset Assignment
# So far, we have just added new columns to our DataFrame. We did not change any of the pre-existing values. Let's begin doing this by changing each person's **`SCORE`** to 100.
#
# The syntax is the same, whether it's adding a new column or changing an existing column:

# %%
df['SCORE'] = 100
df
# Out:
#           GENDER   RACE          DEPARTMENT  YEARS EXPERIENCE  SALARY  SCORE  \
# Tom         Male  White         Engineering                23  107962    100
# Niko        Male  Black         Engineering                 1   30347    100
# Penelope  Female  White         Engineering                12   60258    100
# Aria      Female  Black         Engineering                 8   43618    100
# Sofia     Female  Black  Parks & Recreation                23   26125    100
# Dean        Male  Black  Parks & Recreation                 3   33592    100
# Zach        Male  White  Parks & Recreation                 4   37565    100
#
#           BONUS RATE  FLOOR LAST NAME     BONUS
# Tom             0.20      2       NaN  21592.40
# Niko            0.10      1       NaN   3034.70
# Penelope        0.00      8       NaN      0.00
# Aria            0.15      6       NaN   6542.70
# Sofia           0.12      4       NaN   3135.00
# Dean            0.30      7       NaN  10077.60
# Zach            0.05      3       NaN   1878.25

# %% [markdown]
# ## Overwriting the same column
# You can use the column itself you are assigning in the expression on the right-hand side of the equal sign. For instance, if we want to remove the ugly decimals from the **`BONUS`** column, we can call the **`astype`** method on it and assign it to itself.

# %%
df['BONUS'] = df['BONUS'].astype(int)
df
# Out:
#           GENDER   RACE          DEPARTMENT  YEARS EXPERIENCE  SALARY  SCORE  \
# Tom         Male  White         Engineering                23  107962    100
# Niko        Male  Black         Engineering                 1   30347    100
# Penelope  Female  White         Engineering                12   60258    100
# Aria      Female  Black         Engineering                 8   43618    100
# Sofia     Female  Black  Parks & Recreation                23   26125    100
# Dean        Male  Black  Parks & Recreation                 3   33592    100
# Zach        Male  White  Parks & Recreation                 4   37565    100
#
#           BONUS RATE  FLOOR LAST NAME  BONUS
# Tom             0.20      2       NaN  21592
# Niko            0.10      1       NaN   3034
# Penelope        0.00      8       NaN      0
# Aria            0.15      6       NaN   6542
# Sofia           0.12      4       NaN   3135
# Dean            0.30      7       NaN  10077
# Zach            0.05      3       NaN   1878

# %% [markdown]
# ## Assigning a subset of rows within a single column
# Now that we can change all the values in a single at once, let's learn how to change just a subset of them.
#
# For instance, let's change the **`FLOOR`** for **`Niko`**, **`Penelope`**, and **`Aria`**. Before doing so, let's remember how to make that subset selection with **`.loc`**:

# %%
df.loc[['Niko', 'Penelope', 'Aria'], 'FLOOR']
# Out:
# Niko        1
# Penelope    8
# Aria        6
# Name: FLOOR, dtype: int32

# %% [markdown]
# The **`.loc`** indexer allows for row and column selection separated by a comma. It only makes selections based on row/column **labels**. Once we have correctly selected our subset, let's assign it a list of three new integers

# %%
df.loc[['Niko', 'Penelope', 'Aria'], 'FLOOR'] = [3, 6, 4]
df
# Out:
#           GENDER   RACE          DEPARTMENT  YEARS EXPERIENCE  SALARY  SCORE  \
# Tom         Male  White         Engineering                23  107962    100
# Niko        Male  Black         Engineering                 1   30347    100
# Penelope  Female  White         Engineering                12   60258    100
# Aria      Female  Black         Engineering                 8   43618    100
# Sofia     Female  Black  Parks & Recreation                23   26125    100
# Dean        Male  Black  Parks & Recreation                 3   33592    100
# Zach        Male  White  Parks & Recreation                 4   37565    100
#
#           BONUS RATE  FLOOR LAST NAME  BONUS
# Tom             0.20      2       NaN  21592
# Niko            0.10      3       NaN   3034
# Penelope        0.00      6       NaN      0
# Aria            0.15      4       NaN   6542
# Sofia           0.12      4       NaN   3135
# Dean            0.30      7       NaN  10077
# Zach            0.05      3       NaN   1878

# %% [markdown]
# ## Style DataFrame to show differences (advanced)
# It's not important you understand this section if you are new to pandas, but you should still read through it as the **`style_diff`** function will be used in subsequent sections. Pandas provides a **`style`** attribute which allows you to apply a wide variety of CSS styles to your DataFrames. Check the [style documentation](http://pandas.pydata.org/pandas-docs/stable/style.html) for more.
#
# We are going to change the background color and the color of the text for the values that have changed. To do this, you need to create a copy of the DataFrame before you make any changes with the **`copy`** method.

# %%
df_orig = df.copy()

# %% [markdown]
# Then, we make our changes to our DataFrame

# %%
df.loc[['Niko', 'Penelope', 'Aria'], 'FLOOR'] = [60, 42, 99]
df
# Out:
#           GENDER   RACE          DEPARTMENT  YEARS EXPERIENCE  SALARY  SCORE  \
# Tom         Male  White         Engineering                23  107962    100
# Niko        Male  Black         Engineering                 1   30347    100
# Penelope  Female  White         Engineering                12   60258    100
# Aria      Female  Black         Engineering                 8   43618    100
# Sofia     Female  Black  Parks & Recreation                23   26125    100
# Dean        Male  Black  Parks & Recreation                 3   33592    100
# Zach        Male  White  Parks & Recreation                 4   37565    100
#
#           BONUS RATE  FLOOR LAST NAME  BONUS
# Tom             0.20      2       NaN  21592
# Niko            0.10     60       NaN   3034
# Penelope        0.00     42       NaN      0
# Aria            0.15     99       NaN   6542
# Sofia           0.12      4       NaN   3135
# Dean            0.30      7       NaN  10077
# Zach            0.05      3       NaN   1878

# %% [markdown]
# We can see that the values have changed, but it would be a bit nicer if they stood out more. The function below accepts the entire DataFrame for parameter **`x`** and the original as **`orig`**. It then creates a boolean DataFrame and replaces all the **`False`** values with a semi-colon separated list of new CSS table **`attribute: value`** pairs.

# %%
def style_diff(df, df_orig):
    style = {True: '', 
             False: 'color: red; background-color: yellow'}
    df_style = (df == df_orig).replace(style)
    return df.style.apply(lambda x: df_style, axis=None)

# %% [markdown]
# We can use this function with any DataFrame that we have. But, take care when using a large DataFrame as the style DataFrames **output every single row**. So, if you have a 10,000 row DataFrame, you are probably going to crash your notebook.

# %%
style_diff(df, df_orig)
# Out:
# <style  type="text/css" >
#     #T_d7ef83e8_5605_11e9_a6d5_80ee73d5e3acrow0_col8 {
#             color:  red;
#              background-color:  yellow;
#         }    #T_d7ef83e8_5605_11e9_a6d5_80ee73d5e3acrow1_col7 {
#             color:  red;
#              background-color:  yellow;
#         }    #T_d7ef83e8_5605_11e9_a6d5_80ee73d5e3acrow1_col8 {
#             color:  red;
#              background-color:  yellow;
#         }    #T_d7ef83e8_5605_11e9_a6d5_80ee73d5e3acrow2_col7 {
#             color:  red;
#              background-color:  yellow;
#         }    #T_d7ef83e8_5605_11e9_a6d5_80ee73d5e3acrow2_col8 {
#             color:  red;
#              background-color:  yellow;
#         }    #T_d7ef83e8_5605_11e9_a6d5_80ee73d5e3acrow3_col7 {
#             color:  red;
#              background-color:  yellow;
#         }    #T_d7ef83e8_5605_11e9_a6d5_80ee73d5e3acrow3_col8 {
#             color:  red;
#              background-color:  yellow;
#         }    #T_d7ef83e8_5605_11e9_a6d5_80ee73d5e3acrow4_col8 {
#             color:  red;
#              background-color:  yellow;
#         }    #T_d7ef83e8_5605_11e9_a6d5_80ee73d5e3acrow5_col8 {
#             color:  red;
#              background-color:  yellow;
#         }    #T_d7ef83e8_5605_11e9_a6d5_80ee73d5e3acrow6_col8 {
#             color:  red;
#              background-color:  yellow;
#         }</style><table id="T_d7ef83e8_5605_11e9_a6d5_80ee73d5e3ac" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >GENDER</th>        <th class="col_heading level0 col1" >RACE</th>        <th class="col_heading level0 col2" >DEPARTMENT</th>        <th class="col_heading level0 col3" >YEARS EXPERIENCE</th>        <th class="col_heading level0 col4" >SALARY</th>        <th class="col_heading level0 col5" >SCORE</th>        <th class="col_heading level0 col6" >BONUS RATE</th>        <th class="col_heading level0 col7" >FLOOR</th>        <th class="col_heading level0 col8" >LAST NAME</th>        <th class="col_heading level0 col9" >BONUS</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d7ef83e8_5605_11e9_a6d5_80ee73d5e3aclevel0_row0" class="row_heading level0 row0" >Tom</th>
#                         <td id="T_d7ef83e8_5605_11e9_a6d5_80ee73d5e3acrow0_col0" class="data row0 col0" >Male</td>
#                         <td id="T_d7ef83e8_5605_11e9_a6d5_80ee73d5e3acrow0_col1" class="data row0 col1" >White</td>
#                         <td id="T_d7ef83e8_5605_11e9_a6d5_80ee73d5e3acrow0_col2" class="data row0 col2" >Engineering</td>
#                         <td id="T_d7ef83e8_5605_11e9_a6d5_80ee73d5e3acrow0_col3" class="data row0 col3" >23</td>
#                         <td id="T_d7ef83e8_5605_11e9_a6d5_80ee73d5e3acrow0_col4" class="data row0 col4" >107962</td>
#                         <td id="T_d7ef83e8_5605_11e9_a6d5_80ee73d5e3acrow0_col5" class="data row0 col5" >100</td>
#                         <td id="T_d7ef83e8_5605_11e9_a6d5_80ee73d5e3acrow0_col6" class="data row0 col6" >0.2</td>
#                         <td id="T_d7ef83e8_5605_11e9_a6d5_80ee73d5e3acrow0_col7" class="data row0 col7" >2</td>
#                         <td id="T_d7ef83e8_5605_11e9_a6d5_80ee73d5e3acrow0_col8" class="data row0 col8" >nan</td>
#                         <td id="T_d7ef83e8_5605_11e9_a6d5_80ee73d5e3acrow0_col9" class="data row0 col9" >21592</td>
#             </tr>
#             <tr>
#                         <th id="T_d7ef83e8_5605_11e9_a6d5_80ee73d5e3aclevel0_row1" class="row_heading level0 row1" >Niko</th>
#                         <td id="T_d7ef83e8_5605_11e9_a6d5_80ee73d5e3acrow1_col0" class="data row1 col0" >Male</td>
#                         <td id="T_d7ef83e8_5605_11e9_a6d5_80ee73d5e3acrow1_col1" class="data row1 col1" >Black</td>
#                         <td id="T_d7ef83e8_5605_11e9_a6d5_80ee73d5e3acrow1_col2" class="data row1 col2" >Engineering</td>
#                         <td id="T_d7ef83e8_5605_11e9_a6d5_80ee73d5e3acrow1_col3" class="data row1 col3" >1</td>
#                         <td id="T_d7ef83e8_5605_11e9_a6d5_80ee73d5e3acrow1_col4" class="data row1 col4" >30347</td>
#                         <td id="T_d7ef83e8_5605_11e9_a6d5_80ee73d5e3acrow1_col5" class="data row1 col5" >100</td>
#                         <td id="T_d7ef83e8_5605_11e9_a6d5_80ee73d5e3acrow1_col6" class="data row1 col6" >0.1</td>
#                         <td id="T_d7ef83e8_5605_11e9_a6d5_80ee73d5e3acrow1_col7" class="data row1 col7" >60</td>
#                         <td id="T_d7ef83e8_5605_11e9_a6d5_80ee73d5e3acrow1_col8" class="data row1 col8" >nan</td>
#                         <td id="T_d7ef83e8_5605_11e9_a6d5_80ee73d5e3acrow1_col9" class="data row1 col9" >3034</td>
#             </tr>
#             <tr>
#                         <th id="T_d7ef83e8_5605_11e9_a6d5_80ee73d5e3aclevel0_row2" class="row_heading level0 row2" >Penelope</th>
#                         <td id="T_d7ef83e8_5605_11e9_a6d5_80ee73d5e3acrow2_col0" class="data row2 col0" >Female</td>
#                         <td id="T_d7ef83e8_5605_11e9_a6d5_80ee73d5e3acrow2_col1" class="data row2 col1" >White</td>
#                         <td id="T_d7ef83e8_5605_11e9_a6d5_80ee73d5e3acrow2_col2" class="data row2 col2" >Engineering</td>
#                         <td id="T_d7ef83e8_5605_11e9_a6d5_80ee73d5e3acrow2_col3" class="data row2 col3" >12</td>
#                         <td id="T_d7ef83e8_5605_11e9_a6d5_80ee73d5e3acrow2_col4" class="data row2 col4" >60258</td>
#                         <td id="T_d7ef83e8_5605_11e9_a6d5_80ee73d5e3acrow2_col5" class="data row2 col5" >100</td>
#                         <td id="T_d7ef83e8_5605_11e9_a6d5_80ee73d5e3acrow2_col6" class="data row2 col6" >0</td>
#                         <td id="T_d7ef83e8_5605_11e9_a6d5_80ee73d5e3acrow2_col7" class="data row2 col7" >42</td>
#                         <td id="T_d7ef83e8_5605_11e9_a6d5_80ee73d5e3acrow2_col8" class="data row2 col8" >nan</td>
#                         <td id="T_d7ef83e8_5605_11e9_a6d5_80ee73d5e3acrow2_col9" class="data row2 col9" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_d7ef83e8_5605_11e9_a6d5_80ee73d5e3aclevel0_row3" class="row_heading level0 row3" >Aria</th>
#                         <td id="T_d7ef83e8_5605_11e9_a6d5_80ee73d5e3acrow3_col0" class="data row3 col0" >Female</td>
#                         <td id="T_d7ef83e8_5605_11e9_a6d5_80ee73d5e3acrow3_col1" class="data row3 col1" >Black</td>
#                         <td id="T_d7ef83e8_5605_11e9_a6d5_80ee73d5e3acrow3_col2" class="data row3 col2" >Engineering</td>
#                         <td id="T_d7ef83e8_5605_11e9_a6d5_80ee73d5e3acrow3_col3" class="data row3 col3" >8</td>
#                         <td id="T_d7ef83e8_5605_11e9_a6d5_80ee73d5e3acrow3_col4" class="data row3 col4" >43618</td>
#                         <td id="T_d7ef83e8_5605_11e9_a6d5_80ee73d5e3acrow3_col5" class="data row3 col5" >100</td>
#                         <td id="T_d7ef83e8_5605_11e9_a6d5_80ee73d5e3acrow3_col6" class="data row3 col6" >0.15</td>
#                         <td id="T_d7ef83e8_5605_11e9_a6d5_80ee73d5e3acrow3_col7" class="data row3 col7" >99</td>
#                         <td id="T_d7ef83e8_5605_11e9_a6d5_80ee73d5e3acrow3_col8" class="data row3 col8" >nan</td>
#                         <td id="T_d7ef83e8_5605_11e9_a6d5_80ee73d5e3acrow3_col9" class="data row3 col9" >6542</td>
#             </tr>
#             <tr>
#                         <th id="T_d7ef83e8_5605_11e9_a6d5_80ee73d5e3aclevel0_row4" class="row_heading level0 row4" >Sofia</th>
#                         <td id="T_d7ef83e8_5605_11e9_a6d5_80ee73d5e3acrow4_col0" class="data row4 col0" >Female</td>
#                         <td id="T_d7ef83e8_5605_11e9_a6d5_80ee73d5e3acrow4_col1" class="data row4 col1" >Black</td>
#                         <td id="T_d7ef83e8_5605_11e9_a6d5_80ee73d5e3acrow4_col2" class="data row4 col2" >Parks & Recreation</td>
#                         <td id="T_d7ef83e8_5605_11e9_a6d5_80ee73d5e3acrow4_col3" class="data row4 col3" >23</td>
#                         <td id="T_d7ef83e8_5605_11e9_a6d5_80ee73d5e3acrow4_col4" class="data

# %% [markdown]
# ## Assigning subsets with `.iloc`
# Similarly, we can use the **`.iloc`** indexer which only makes selections via **`integer location`**.
#
# Let's assign the 3rd - 6th rows of the **`SCORE`** column (integer location 5) with the value 99. Again, we will make a copy of the DataFrame and display the difference with our **`style_diff`** function.

# %%
df_orig = df.copy()

df.iloc[3:6, 5] = 99

# %%
style_diff(df, df_orig)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-169-565ea6278dd3> in <module>
# ----> 1 style_diff(df, df_orig)
#
# <ipython-input-165-df94a841457d> in style_diff(df, df_orig)
#       2     style = {True: '',
#       3              False: 'color: red; background-color: yellow'}
# ----> 4     df_style = (df == df_orig).replace(style)
#       5     return df.style.apply(lambda x: df_style, axis=None)
#
# c:\users\takim\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\ops.py in f(self, other)
#    2094             # Another DataFrame
#    2095             if not self._indexed_same(other):
# -> 2096                 raise ValueError('Can only compare identically-labeled '
#    2097                                  'DataFrame objects')
#    2098             return dispatch_to_series(self, other, func, str_rep)
#
# ValueError: Can only compare identically-labeled DataFrame objects

# %% [markdown]
# ## Assigning an entire column with `.loc` and `.iloc`
# Normally, *just the indexing operator* is used to change values of an entire column, but it's also possible to do it with both **`.loc`** and **.`iloc`**. You have to remember that the fist selection made by both these indexers is the rows. To select all rows, use the colon **`:`**.
#
# For instance, let's see this in action by changing all values in the **`FLOOR`** column.

# %%
df_orig = df.copy()
df.loc[:, 'FLOOR'] = 33
style_diff(df, df_orig)
# Out:
# <style  type="text/css" >
#     #T_d862802c_5605_11e9_82e2_80ee73d5e3acrow0_col7 {
#             color:  red;
#              background-color:  yellow;
#         }    #T_d862802c_5605_11e9_82e2_80ee73d5e3acrow0_col8 {
#             color:  red;
#              background-color:  yellow;
#         }    #T_d862802c_5605_11e9_82e2_80ee73d5e3acrow1_col7 {
#             color:  red;
#              background-color:  yellow;
#         }    #T_d862802c_5605_11e9_82e2_80ee73d5e3acrow1_col8 {
#             color:  red;
#              background-color:  yellow;
#         }    #T_d862802c_5605_11e9_82e2_80ee73d5e3acrow2_col7 {
#             color:  red;
#              background-color:  yellow;
#         }    #T_d862802c_5605_11e9_82e2_80ee73d5e3acrow2_col8 {
#             color:  red;
#              background-color:  yellow;
#         }    #T_d862802c_5605_11e9_82e2_80ee73d5e3acrow3_col7 {
#             color:  red;
#              background-color:  yellow;
#         }    #T_d862802c_5605_11e9_82e2_80ee73d5e3acrow3_col8 {
#             color:  red;
#              background-color:  yellow;
#         }    #T_d862802c_5605_11e9_82e2_80ee73d5e3acrow4_col7 {
#             color:  red;
#              background-color:  yellow;
#         }    #T_d862802c_5605_11e9_82e2_80ee73d5e3acrow4_col8 {
#             color:  red;
#              background-color:  yellow;
#         }    #T_d862802c_5605_11e9_82e2_80ee73d5e3acrow5_col7 {
#             color:  red;
#              background-color:  yellow;
#         }    #T_d862802c_5605_11e9_82e2_80ee73d5e3acrow5_col8 {
#             color:  red;
#              background-color:  yellow;
#         }    #T_d862802c_5605_11e9_82e2_80ee73d5e3acrow6_col7 {
#             color:  red;
#              background-color:  yellow;
#         }    #T_d862802c_5605_11e9_82e2_80ee73d5e3acrow6_col8 {
#             color:  red;
#              background-color:  yellow;
#         }</style><table id="T_d862802c_5605_11e9_82e2_80ee73d5e3ac" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >GENDER</th>        <th class="col_heading level0 col1" >RACE</th>        <th class="col_heading level0 col2" >DEPARTMENT</th>        <th class="col_heading level0 col3" >YEARS EXPERIENCE</th>        <th class="col_heading level0 col4" >SALARY</th>        <th class="col_heading level0 col5" >SCORE</th>        <th class="col_heading level0 col6" >BONUS RATE</th>        <th class="col_heading level0 col7" >FLOOR</th>        <th class="col_heading level0 col8" >LAST NAME</th>        <th class="col_heading level0 col9" >BONUS</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d862802c_5605_11e9_82e2_80ee73d5e3aclevel0_row0" class="row_heading level0 row0" >Tom</th>
#                         <td id="T_d862802c_5605_11e9_82e2_80ee73d5e3acrow0_col0" class="data row0 col0" >Male</td>
#                         <td id="T_d862802c_5605_11e9_82e2_80ee73d5e3acrow0_col1" class="data row0 col1" >White</td>
#                         <td id="T_d862802c_5605_11e9_82e2_80ee73d5e3acrow0_col2" class="data row0 col2" >Engineering</td>
#                         <td id="T_d862802c_5605_11e9_82e2_80ee73d5e3acrow0_col3" class="data row0 col3" >23</td>
#                         <td id="T_d862802c_5605_11e9_82e2_80ee73d5e3acrow0_col4" class="data row0 col4" >107962</td>
#                         <td id="T_d862802c_5605_11e9_82e2_80ee73d5e3acrow0_col5" class="data row0 col5" >100</td>
#                         <td id="T_d862802c_5605_11e9_82e2_80ee73d5e3acrow0_col6" class="data row0 col6" >0.2</td>
#                         <td id="T_d862802c_5605_11e9_82e2_80ee73d5e3acrow0_col7" class="data row0 col7" >33</td>
#                         <td id="T_d862802c_5605_11e9_82e2_80ee73d5e3acrow0_col8" class="data row0 col8" >nan</td>
#                         <td id="T_d862802c_5605_11e9_82e2_80ee73d5e3acrow0_col9" class="data row0 col9" >21592</td>
#             </tr>
#             <tr>
#                         <th id="T_d862802c_5605_11e9_82e2_80ee73d5e3aclevel0_row1" class="row_heading level0 row1" >Niko</th>
#                         <td id="T_d862802c_5605_11e9_82e2_80ee73d5e3acrow1_col0" class="data row1 col0" >Male</td>
#                         <td id="T_d862802c_5605_11e9_82e2_80ee73d5e3acrow1_col1" class="data row1 col1" >Black</td>
#                         <td id="T_d862802c_5605_11e9_82e2_80ee73d5e3acrow1_col2" class="data row1 col2" >Engineering</td>
#                         <td id="T_d862802c_5605_11e9_82e2_80ee73d5e3acrow1_col3" class="data row1 col3" >1</td>
#                         <td id="T_d862802c_5605_11e9_82e2_80ee73d5e3acrow1_col4" class="data row1 col4" >30347</td>
#                         <td id="T_d862802c_5605_11e9_82e2_80ee73d5e3acrow1_col5" class="data row1 col5" >100</td>
#                         <td id="T_d862802c_5605_11e9_82e2_80ee73d5e3acrow1_col6" class="data row1 col6" >0.1</td>
#                         <td id="T_d862802c_5605_11e9_82e2_80ee73d5e3acrow1_col7" class="data row1 col7" >33</td>
#                         <td id="T_d862802c_5605_11e9_82e2_80ee73d5e3acrow1_col8" class="data row1 col8" >nan</td>
#                         <td id="T_d862802c_5605_11e9_82e2_80ee73d5e3acrow1_col9" class="data row1 col9" >3034</td>
#             </tr>
#             <tr>
#                         <th id="T_d862802c_5605_11e9_82e2_80ee73d5e3aclevel0_row2" class="row_heading level0 row2" >Penelope</th>
#                         <td id="T_d862802c_5605_11e9_82e2_80ee73d5e3acrow2_col0" class="data row2 col0" >Female</td>
#                         <td id="T_d862802c_5605_11e9_82e2_80ee73d5e3acrow2_col1" class="data row2 col1" >White</td>
#                         <td id="T_d862802c_5605_11e9_82e2_80ee73d5e3acrow2_col2" class="data row2 col2" >Engineering</td>
#                         <td id="T_d862802c_5605_11e9_82e2_80ee73d5e3acrow2_col3" class="data row2 col3" >12</td>
#                         <td id="T_d862802c_5605_11e9_82e2_80ee73d5e3acrow2_col4" class="data row2 col4" >60258</td>
#                         <td id="T_d862802c_5605_11e9_82e2_80ee73d5e3acrow2_col5" class="data row2 col5" >100</td>
#                         <td id="T_d862802c_5605_11e9_82e2_80ee73d5e3acrow2_col6" class="data row2 col6" >0</td>
#                         <td id="T_d862802c_5605_11e9_82e2_80ee73d5e3acrow2_col7" class="data row2 col7" >33</td>
#                         <td id="T_d862802c_5605_11e9_82e2_80ee73d5e3acrow2_col8" class="data row2 col8" >nan</td>
#                         <td id="T_d862802c_5605_11e9_82e2_80ee73d5e3acrow2_col9" class="data row2 col9" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_d862802c_5605_11e9_82e2_80ee73d5e3aclevel0_row3" class="row_heading level0 row3" >Aria</th>
#                         <td id="T_d862802c_5605_11e9_82e2_80ee73d5e3acrow3_col0" class="data row3 col0" >Female</td>
#                         <td id="T_d862802c_5605_11e9_82e2_80ee73d5e3acrow3_col1" class="data row3 col1" >Black</td>
#                         <td id="T_d862802c_5605_11e9_82e2_80ee73d5e3acrow3_col2" class="data row3 col2" >Engineering</td>
#                         <td id="T_d862802c_5605_11e9_82e2_80ee73d5e3acrow3_col3" class="data row3 col3" >8</td>
#                         <td id="T_d862802c_5605_11e9_82e2_80ee73d5e3acrow3_col4" class="data row3 col4" >43618</td>
#                         <td id="T_d862802c_5605_11e9_82e2_80ee73d5e3acrow3_col5" class="data row3 col5" >99</td>
#                         <td id="T_d862802c_5605_11e9_82e2_80ee73d5e3acrow3_col6" class="data row3 col6" >0.15</td>
#                         <td id="T_d862802c_5605_11e9_82e2_80ee73d5e3acrow3_col7" class="data row3 col7" >33</td>
#                         <td id="T_d862802c_5605_11e9_82e2_80ee73d5e3acrow3_col8" class="data row3 col8" >nan</td>
#                         <td id="T_d862802c_5605_11e9_82e2_80ee73d5e3acrow3_col9" class="data row3 col9" >6542</td>
#             </tr>
#             <tr>
#                         <th id="T_d862802c_5605_11e9_82e2_80ee73d5e3aclevel0_row4" class="row_heading level0 row4" >Sofia</th>
#                         <td id="T_d862802c_5605_11e

# %% [markdown]
# And with **`.iloc`**:

# %%
df_orig = df.copy()
df.iloc[:, 7] = 22
style_diff(df, df_orig)
# Out:
# <style  type="text/css" >
#     #T_d88c6cf8_5605_11e9_8ea6_80ee73d5e3acrow0_col7 {
#             color:  red;
#              background-color:  yellow;
#         }    #T_d88c6cf8_5605_11e9_8ea6_80ee73d5e3acrow0_col8 {
#             color:  red;
#              background-color:  yellow;
#         }    #T_d88c6cf8_5605_11e9_8ea6_80ee73d5e3acrow1_col7 {
#             color:  red;
#              background-color:  yellow;
#         }    #T_d88c6cf8_5605_11e9_8ea6_80ee73d5e3acrow1_col8 {
#             color:  red;
#              background-color:  yellow;
#         }    #T_d88c6cf8_5605_11e9_8ea6_80ee73d5e3acrow2_col7 {
#             color:  red;
#              background-color:  yellow;
#         }    #T_d88c6cf8_5605_11e9_8ea6_80ee73d5e3acrow2_col8 {
#             color:  red;
#              background-color:  yellow;
#         }    #T_d88c6cf8_5605_11e9_8ea6_80ee73d5e3acrow3_col7 {
#             color:  red;
#              background-color:  yellow;
#         }    #T_d88c6cf8_5605_11e9_8ea6_80ee73d5e3acrow3_col8 {
#             color:  red;
#              background-color:  yellow;
#         }    #T_d88c6cf8_5605_11e9_8ea6_80ee73d5e3acrow4_col7 {
#             color:  red;
#              background-color:  yellow;
#         }    #T_d88c6cf8_5605_11e9_8ea6_80ee73d5e3acrow4_col8 {
#             color:  red;
#              background-color:  yellow;
#         }    #T_d88c6cf8_5605_11e9_8ea6_80ee73d5e3acrow5_col7 {
#             color:  red;
#              background-color:  yellow;
#         }    #T_d88c6cf8_5605_11e9_8ea6_80ee73d5e3acrow5_col8 {
#             color:  red;
#              background-color:  yellow;
#         }    #T_d88c6cf8_5605_11e9_8ea6_80ee73d5e3acrow6_col7 {
#             color:  red;
#              background-color:  yellow;
#         }    #T_d88c6cf8_5605_11e9_8ea6_80ee73d5e3acrow6_col8 {
#             color:  red;
#              background-color:  yellow;
#         }</style><table id="T_d88c6cf8_5605_11e9_8ea6_80ee73d5e3ac" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >GENDER</th>        <th class="col_heading level0 col1" >RACE</th>        <th class="col_heading level0 col2" >DEPARTMENT</th>        <th class="col_heading level0 col3" >YEARS EXPERIENCE</th>        <th class="col_heading level0 col4" >SALARY</th>        <th class="col_heading level0 col5" >SCORE</th>        <th class="col_heading level0 col6" >BONUS RATE</th>        <th class="col_heading level0 col7" >FLOOR</th>        <th class="col_heading level0 col8" >LAST NAME</th>        <th class="col_heading level0 col9" >BONUS</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d88c6cf8_5605_11e9_8ea6_80ee73d5e3aclevel0_row0" class="row_heading level0 row0" >Tom</th>
#                         <td id="T_d88c6cf8_5605_11e9_8ea6_80ee73d5e3acrow0_col0" class="data row0 col0" >Male</td>
#                         <td id="T_d88c6cf8_5605_11e9_8ea6_80ee73d5e3acrow0_col1" class="data row0 col1" >White</td>
#                         <td id="T_d88c6cf8_5605_11e9_8ea6_80ee73d5e3acrow0_col2" class="data row0 col2" >Engineering</td>
#                         <td id="T_d88c6cf8_5605_11e9_8ea6_80ee73d5e3acrow0_col3" class="data row0 col3" >23</td>
#                         <td id="T_d88c6cf8_5605_11e9_8ea6_80ee73d5e3acrow0_col4" class="data row0 col4" >107962</td>
#                         <td id="T_d88c6cf8_5605_11e9_8ea6_80ee73d5e3acrow0_col5" class="data row0 col5" >100</td>
#                         <td id="T_d88c6cf8_5605_11e9_8ea6_80ee73d5e3acrow0_col6" class="data row0 col6" >0.2</td>
#                         <td id="T_d88c6cf8_5605_11e9_8ea6_80ee73d5e3acrow0_col7" class="data row0 col7" >22</td>
#                         <td id="T_d88c6cf8_5605_11e9_8ea6_80ee73d5e3acrow0_col8" class="data row0 col8" >nan</td>
#                         <td id="T_d88c6cf8_5605_11e9_8ea6_80ee73d5e3acrow0_col9" class="data row0 col9" >21592</td>
#             </tr>
#             <tr>
#                         <th id="T_d88c6cf8_5605_11e9_8ea6_80ee73d5e3aclevel0_row1" class="row_heading level0 row1" >Niko</th>
#                         <td id="T_d88c6cf8_5605_11e9_8ea6_80ee73d5e3acrow1_col0" class="data row1 col0" >Male</td>
#                         <td id="T_d88c6cf8_5605_11e9_8ea6_80ee73d5e3acrow1_col1" class="data row1 col1" >Black</td>
#                         <td id="T_d88c6cf8_5605_11e9_8ea6_80ee73d5e3acrow1_col2" class="data row1 col2" >Engineering</td>
#                         <td id="T_d88c6cf8_5605_11e9_8ea6_80ee73d5e3acrow1_col3" class="data row1 col3" >1</td>
#                         <td id="T_d88c6cf8_5605_11e9_8ea6_80ee73d5e3acrow1_col4" class="data row1 col4" >30347</td>
#                         <td id="T_d88c6cf8_5605_11e9_8ea6_80ee73d5e3acrow1_col5" class="data row1 col5" >100</td>
#                         <td id="T_d88c6cf8_5605_11e9_8ea6_80ee73d5e3acrow1_col6" class="data row1 col6" >0.1</td>
#                         <td id="T_d88c6cf8_5605_11e9_8ea6_80ee73d5e3acrow1_col7" class="data row1 col7" >22</td>
#                         <td id="T_d88c6cf8_5605_11e9_8ea6_80ee73d5e3acrow1_col8" class="data row1 col8" >nan</td>
#                         <td id="T_d88c6cf8_5605_11e9_8ea6_80ee73d5e3acrow1_col9" class="data row1 col9" >3034</td>
#             </tr>
#             <tr>
#                         <th id="T_d88c6cf8_5605_11e9_8ea6_80ee73d5e3aclevel0_row2" class="row_heading level0 row2" >Penelope</th>
#                         <td id="T_d88c6cf8_5605_11e9_8ea6_80ee73d5e3acrow2_col0" class="data row2 col0" >Female</td>
#                         <td id="T_d88c6cf8_5605_11e9_8ea6_80ee73d5e3acrow2_col1" class="data row2 col1" >White</td>
#                         <td id="T_d88c6cf8_5605_11e9_8ea6_80ee73d5e3acrow2_col2" class="data row2 col2" >Engineering</td>
#                         <td id="T_d88c6cf8_5605_11e9_8ea6_80ee73d5e3acrow2_col3" class="data row2 col3" >12</td>
#                         <td id="T_d88c6cf8_5605_11e9_8ea6_80ee73d5e3acrow2_col4" class="data row2 col4" >60258</td>
#                         <td id="T_d88c6cf8_5605_11e9_8ea6_80ee73d5e3acrow2_col5" class="data row2 col5" >100</td>
#                         <td id="T_d88c6cf8_5605_11e9_8ea6_80ee73d5e3acrow2_col6" class="data row2 col6" >0</td>
#                         <td id="T_d88c6cf8_5605_11e9_8ea6_80ee73d5e3acrow2_col7" class="data row2 col7" >22</td>
#                         <td id="T_d88c6cf8_5605_11e9_8ea6_80ee73d5e3acrow2_col8" class="data row2 col8" >nan</td>
#                         <td id="T_d88c6cf8_5605_11e9_8ea6_80ee73d5e3acrow2_col9" class="data row2 col9" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_d88c6cf8_5605_11e9_8ea6_80ee73d5e3aclevel0_row3" class="row_heading level0 row3" >Aria</th>
#                         <td id="T_d88c6cf8_5605_11e9_8ea6_80ee73d5e3acrow3_col0" class="data row3 col0" >Female</td>
#                         <td id="T_d88c6cf8_5605_11e9_8ea6_80ee73d5e3acrow3_col1" class="data row3 col1" >Black</td>
#                         <td id="T_d88c6cf8_5605_11e9_8ea6_80ee73d5e3acrow3_col2" class="data row3 col2" >Engineering</td>
#                         <td id="T_d88c6cf8_5605_11e9_8ea6_80ee73d5e3acrow3_col3" class="data row3 col3" >8</td>
#                         <td id="T_d88c6cf8_5605_11e9_8ea6_80ee73d5e3acrow3_col4" class="data row3 col4" >43618</td>
#                         <td id="T_d88c6cf8_5605_11e9_8ea6_80ee73d5e3acrow3_col5" class="data row3 col5" >99</td>
#                         <td id="T_d88c6cf8_5605_11e9_8ea6_80ee73d5e3acrow3_col6" class="data row3 col6" >0.15</td>
#                         <td id="T_d88c6cf8_5605_11e9_8ea6_80ee73d5e3acrow3_col7" class="data row3 col7" >22</td>
#                         <td id="T_d88c6cf8_5605_11e9_8ea6_80ee73d5e3acrow3_col8" class="data row3 col8" >nan</td>
#                         <td id="T_d88c6cf8_5605_11e9_8ea6_80ee73d5e3acrow3_col9" class="data row3 col9" >6542</td>
#             </tr>
#             <tr>
#                         <th id="T_d88c6cf8_5605_11e9_8ea6_80ee73d5e3aclevel0_row4" class="row_heading level0 row4" >Sofia</th>
#                         <td id="T_d88c6cf8_5605_11e

# %% [markdown]
# ## Assigning with boolean selection
# It is more common to use boolean selection to make assignments to subsets than with directly selecting subsets by label or integer location.
#
# For instance, let's say we wanted to give everyone in the engineering department a $5,000 bonus on top of what they already have.
#
# Before making the assignment, let's properly select the data with boolean indexing.

# %%
df.loc[df['DEPARTMENT'] == 'Engineering', 'BONUS']
# Out:
# Tom         21592
# Niko         3034
# Penelope        0
# Aria         6542
# Name: BONUS, dtype: int32

# %% [markdown]
# Once we have confirmed that our selection works, we can make an assignment. We can use the **`+=`** operator to shorten the syntax considerably, which will assign the value back to itself.

# %%
df_orig = df.copy()

df.loc[df['DEPARTMENT'] == 'Engineering', 'BONUS'] += 5000
style_diff(df, df_orig)
# Out:
# <style  type="text/css" >
#     #T_d934a4de_5605_11e9_a295_80ee73d5e3acrow0_col8 {
#             color:  red;
#              background-color:  yellow;
#         }    #T_d934a4de_5605_11e9_a295_80ee73d5e3acrow0_col9 {
#             color:  red;
#              background-color:  yellow;
#         }    #T_d934a4de_5605_11e9_a295_80ee73d5e3acrow1_col8 {
#             color:  red;
#              background-color:  yellow;
#         }    #T_d934a4de_5605_11e9_a295_80ee73d5e3acrow1_col9 {
#             color:  red;
#              background-color:  yellow;
#         }    #T_d934a4de_5605_11e9_a295_80ee73d5e3acrow2_col8 {
#             color:  red;
#              background-color:  yellow;
#         }    #T_d934a4de_5605_11e9_a295_80ee73d5e3acrow2_col9 {
#             color:  red;
#              background-color:  yellow;
#         }    #T_d934a4de_5605_11e9_a295_80ee73d5e3acrow3_col8 {
#             color:  red;
#              background-color:  yellow;
#         }    #T_d934a4de_5605_11e9_a295_80ee73d5e3acrow3_col9 {
#             color:  red;
#              background-color:  yellow;
#         }    #T_d934a4de_5605_11e9_a295_80ee73d5e3acrow4_col8 {
#             color:  red;
#              background-color:  yellow;
#         }    #T_d934a4de_5605_11e9_a295_80ee73d5e3acrow5_col8 {
#             color:  red;
#              background-color:  yellow;
#         }    #T_d934a4de_5605_11e9_a295_80ee73d5e3acrow6_col8 {
#             color:  red;
#              background-color:  yellow;
#         }</style><table id="T_d934a4de_5605_11e9_a295_80ee73d5e3ac" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >GENDER</th>        <th class="col_heading level0 col1" >RACE</th>        <th class="col_heading level0 col2" >DEPARTMENT</th>        <th class="col_heading level0 col3" >YEARS EXPERIENCE</th>        <th class="col_heading level0 col4" >SALARY</th>        <th class="col_heading level0 col5" >SCORE</th>        <th class="col_heading level0 col6" >BONUS RATE</th>        <th class="col_heading level0 col7" >FLOOR</th>        <th class="col_heading level0 col8" >LAST NAME</th>        <th class="col_heading level0 col9" >BONUS</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d934a4de_5605_11e9_a295_80ee73d5e3aclevel0_row0" class="row_heading level0 row0" >Tom</th>
#                         <td id="T_d934a4de_5605_11e9_a295_80ee73d5e3acrow0_col0" class="data row0 col0" >Male</td>
#                         <td id="T_d934a4de_5605_11e9_a295_80ee73d5e3acrow0_col1" class="data row0 col1" >White</td>
#                         <td id="T_d934a4de_5605_11e9_a295_80ee73d5e3acrow0_col2" class="data row0 col2" >Engineering</td>
#                         <td id="T_d934a4de_5605_11e9_a295_80ee73d5e3acrow0_col3" class="data row0 col3" >23</td>
#                         <td id="T_d934a4de_5605_11e9_a295_80ee73d5e3acrow0_col4" class="data row0 col4" >107962</td>
#                         <td id="T_d934a4de_5605_11e9_a295_80ee73d5e3acrow0_col5" class="data row0 col5" >100</td>
#                         <td id="T_d934a4de_5605_11e9_a295_80ee73d5e3acrow0_col6" class="data row0 col6" >0.2</td>
#                         <td id="T_d934a4de_5605_11e9_a295_80ee73d5e3acrow0_col7" class="data row0 col7" >22</td>
#                         <td id="T_d934a4de_5605_11e9_a295_80ee73d5e3acrow0_col8" class="data row0 col8" >nan</td>
#                         <td id="T_d934a4de_5605_11e9_a295_80ee73d5e3acrow0_col9" class="data row0 col9" >26592</td>
#             </tr>
#             <tr>
#                         <th id="T_d934a4de_5605_11e9_a295_80ee73d5e3aclevel0_row1" class="row_heading level0 row1" >Niko</th>
#                         <td id="T_d934a4de_5605_11e9_a295_80ee73d5e3acrow1_col0" class="data row1 col0" >Male</td>
#                         <td id="T_d934a4de_5605_11e9_a295_80ee73d5e3acrow1_col1" class="data row1 col1" >Black</td>
#                         <td id="T_d934a4de_5605_11e9_a295_80ee73d5e3acrow1_col2" class="data row1 col2" >Engineering</td>
#                         <td id="T_d934a4de_5605_11e9_a295_80ee73d5e3acrow1_col3" class="data row1 col3" >1</td>
#                         <td id="T_d934a4de_5605_11e9_a295_80ee73d5e3acrow1_col4" class="data row1 col4" >30347</td>
#                         <td id="T_d934a4de_5605_11e9_a295_80ee73d5e3acrow1_col5" class="data row1 col5" >100</td>
#                         <td id="T_d934a4de_5605_11e9_a295_80ee73d5e3acrow1_col6" class="data row1 col6" >0.1</td>
#                         <td id="T_d934a4de_5605_11e9_a295_80ee73d5e3acrow1_col7" class="data row1 col7" >22</td>
#                         <td id="T_d934a4de_5605_11e9_a295_80ee73d5e3acrow1_col8" class="data row1 col8" >nan</td>
#                         <td id="T_d934a4de_5605_11e9_a295_80ee73d5e3acrow1_col9" class="data row1 col9" >8034</td>
#             </tr>
#             <tr>
#                         <th id="T_d934a4de_5605_11e9_a295_80ee73d5e3aclevel0_row2" class="row_heading level0 row2" >Penelope</th>
#                         <td id="T_d934a4de_5605_11e9_a295_80ee73d5e3acrow2_col0" class="data row2 col0" >Female</td>
#                         <td id="T_d934a4de_5605_11e9_a295_80ee73d5e3acrow2_col1" class="data row2 col1" >White</td>
#                         <td id="T_d934a4de_5605_11e9_a295_80ee73d5e3acrow2_col2" class="data row2 col2" >Engineering</td>
#                         <td id="T_d934a4de_5605_11e9_a295_80ee73d5e3acrow2_col3" class="data row2 col3" >12</td>
#                         <td id="T_d934a4de_5605_11e9_a295_80ee73d5e3acrow2_col4" class="data row2 col4" >60258</td>
#                         <td id="T_d934a4de_5605_11e9_a295_80ee73d5e3acrow2_col5" class="data row2 col5" >100</td>
#                         <td id="T_d934a4de_5605_11e9_a295_80ee73d5e3acrow2_col6" class="data row2 col6" >0</td>
#                         <td id="T_d934a4de_5605_11e9_a295_80ee73d5e3acrow2_col7" class="data row2 col7" >22</td>
#                         <td id="T_d934a4de_5605_11e9_a295_80ee73d5e3acrow2_col8" class="data row2 col8" >nan</td>
#                         <td id="T_d934a4de_5605_11e9_a295_80ee73d5e3acrow2_col9" class="data row2 col9" >5000</td>
#             </tr>
#             <tr>
#                         <th id="T_d934a4de_5605_11e9_a295_80ee73d5e3aclevel0_row3" class="row_heading level0 row3" >Aria</th>
#                         <td id="T_d934a4de_5605_11e9_a295_80ee73d5e3acrow3_col0" class="data row3 col0" >Female</td>
#                         <td id="T_d934a4de_5605_11e9_a295_80ee73d5e3acrow3_col1" class="data row3 col1" >Black</td>
#                         <td id="T_d934a4de_5605_11e9_a295_80ee73d5e3acrow3_col2" class="data row3 col2" >Engineering</td>
#                         <td id="T_d934a4de_5605_11e9_a295_80ee73d5e3acrow3_col3" class="data row3 col3" >8</td>
#                         <td id="T_d934a4de_5605_11e9_a295_80ee73d5e3acrow3_col4" class="data row3 col4" >43618</td>
#                         <td id="T_d934a4de_5605_11e9_a295_80ee73d5e3acrow3_col5" class="data row3 col5" >99</td>
#                         <td id="T_d934a4de_5605_11e9_a295_80ee73d5e3acrow3_col6" class="data row3 col6" >0.15</td>
#                         <td id="T_d934a4de_5605_11e9_a295_80ee73d5e3acrow3_col7" class="data row3 col7" >22</td>
#                         <td id="T_d934a4de_5605_11e9_a295_80ee73d5e3acrow3_col8" class="data row3 col8" >nan</td>
#                         <td id="T_d934a4de_5605_11e9_a295_80ee73d5e3acrow3_col9" class="data row3 col9" >11542</td>
#             </tr>
#             <tr>
#                         <th id="T_d934a4de_5605_11e9_a295_80ee73d5e3aclevel0_row4" class="row_heading level0 row4" >Sofia</th>
#                         <td id="T_d934a4de_5605_11e9_a295_80ee73d5e3acrow4_col0" class="data row4 col0" >Female</td>
#                         <td id="T_d934a4de_5605_11e9_a295_80ee73d5e3acrow4_col1" class="data row4 col1" >Black</td>
#                         <td id="T_d934a4de_5605_11e9_a295_80ee73d5e3acrow4_col2" class="data row4 col2" >Parks & Recreation</td>
#                         <td id="T_d934a4de_5605_11e9_a295_80ee73d5e3acro

# %% [markdown]
# ## Assigning with multiple condition boolean selection
# Let's do an example with multiple boolean conditions. Let's subtract 10 from the **`SCORE`** of all the black females and white males.

# %%
# check our logic first
white_male = (df['GENDER'] == 'Male') & (df['RACE'] == 'White')
black_female = (df['GENDER'] == 'Female') & (df['RACE'] == 'Black')
criteria = white_male | black_female
df[criteria]
# Out:
#        GENDER   RACE          DEPARTMENT  YEARS EXPERIENCE  SALARY  SCORE  \
# Tom      Male  White         Engineering                23  107962    100
# Aria   Female  Black         Engineering                 8   43618     99
# Sofia  Female  Black  Parks & Recreation                23   26125     99
# Zach     Male  White  Parks & Recreation                 4   37565    100
#
#        BONUS RATE  FLOOR LAST NAME  BONUS
# Tom          0.20     22       NaN  26592
# Aria         0.15     22       NaN  11542
# Sofia        0.12     22       NaN   3135
# Zach         0.05     22       NaN   1878

# %%
df_orig = df.copy()
df.loc[criteria, 'SCORE'] -= 10
style_diff(df, df_orig)
# Out:
# <style  type="text/css" >
#     #T_da4233c6_5605_11e9_9c4b_80ee73d5e3acrow0_col5 {
#             color:  red;
#              background-color:  yellow;
#         }    #T_da4233c6_5605_11e9_9c4b_80ee73d5e3acrow0_col8 {
#             color:  red;
#              background-color:  yellow;
#         }    #T_da4233c6_5605_11e9_9c4b_80ee73d5e3acrow1_col8 {
#             color:  red;
#              background-color:  yellow;
#         }    #T_da4233c6_5605_11e9_9c4b_80ee73d5e3acrow2_col8 {
#             color:  red;
#              background-color:  yellow;
#         }    #T_da4233c6_5605_11e9_9c4b_80ee73d5e3acrow3_col5 {
#             color:  red;
#              background-color:  yellow;
#         }    #T_da4233c6_5605_11e9_9c4b_80ee73d5e3acrow3_col8 {
#             color:  red;
#              background-color:  yellow;
#         }    #T_da4233c6_5605_11e9_9c4b_80ee73d5e3acrow4_col5 {
#             color:  red;
#              background-color:  yellow;
#         }    #T_da4233c6_5605_11e9_9c4b_80ee73d5e3acrow4_col8 {
#             color:  red;
#              background-color:  yellow;
#         }    #T_da4233c6_5605_11e9_9c4b_80ee73d5e3acrow5_col8 {
#             color:  red;
#              background-color:  yellow;
#         }    #T_da4233c6_5605_11e9_9c4b_80ee73d5e3acrow6_col5 {
#             color:  red;
#              background-color:  yellow;
#         }    #T_da4233c6_5605_11e9_9c4b_80ee73d5e3acrow6_col8 {
#             color:  red;
#              background-color:  yellow;
#         }</style><table id="T_da4233c6_5605_11e9_9c4b_80ee73d5e3ac" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >GENDER</th>        <th class="col_heading level0 col1" >RACE</th>        <th class="col_heading level0 col2" >DEPARTMENT</th>        <th class="col_heading level0 col3" >YEARS EXPERIENCE</th>        <th class="col_heading level0 col4" >SALARY</th>        <th class="col_heading level0 col5" >SCORE</th>        <th class="col_heading level0 col6" >BONUS RATE</th>        <th class="col_heading level0 col7" >FLOOR</th>        <th class="col_heading level0 col8" >LAST NAME</th>        <th class="col_heading level0 col9" >BONUS</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_da4233c6_5605_11e9_9c4b_80ee73d5e3aclevel0_row0" class="row_heading level0 row0" >Tom</th>
#                         <td id="T_da4233c6_5605_11e9_9c4b_80ee73d5e3acrow0_col0" class="data row0 col0" >Male</td>
#                         <td id="T_da4233c6_5605_11e9_9c4b_80ee73d5e3acrow0_col1" class="data row0 col1" >White</td>
#                         <td id="T_da4233c6_5605_11e9_9c4b_80ee73d5e3acrow0_col2" class="data row0 col2" >Engineering</td>
#                         <td id="T_da4233c6_5605_11e9_9c4b_80ee73d5e3acrow0_col3" class="data row0 col3" >23</td>
#                         <td id="T_da4233c6_5605_11e9_9c4b_80ee73d5e3acrow0_col4" class="data row0 col4" >107962</td>
#                         <td id="T_da4233c6_5605_11e9_9c4b_80ee73d5e3acrow0_col5" class="data row0 col5" >90</td>
#                         <td id="T_da4233c6_5605_11e9_9c4b_80ee73d5e3acrow0_col6" class="data row0 col6" >0.2</td>
#                         <td id="T_da4233c6_5605_11e9_9c4b_80ee73d5e3acrow0_col7" class="data row0 col7" >22</td>
#                         <td id="T_da4233c6_5605_11e9_9c4b_80ee73d5e3acrow0_col8" class="data row0 col8" >nan</td>
#                         <td id="T_da4233c6_5605_11e9_9c4b_80ee73d5e3acrow0_col9" class="data row0 col9" >26592</td>
#             </tr>
#             <tr>
#                         <th id="T_da4233c6_5605_11e9_9c4b_80ee73d5e3aclevel0_row1" class="row_heading level0 row1" >Niko</th>
#                         <td id="T_da4233c6_5605_11e9_9c4b_80ee73d5e3acrow1_col0" class="data row1 col0" >Male</td>
#                         <td id="T_da4233c6_5605_11e9_9c4b_80ee73d5e3acrow1_col1" class="data row1 col1" >Black</td>
#                         <td id="T_da4233c6_5605_11e9_9c4b_80ee73d5e3acrow1_col2" class="data row1 col2" >Engineering</td>
#                         <td id="T_da4233c6_5605_11e9_9c4b_80ee73d5e3acrow1_col3" class="data row1 col3" >1</td>
#                         <td id="T_da4233c6_5605_11e9_9c4b_80ee73d5e3acrow1_col4" class="data row1 col4" >30347</td>
#                         <td id="T_da4233c6_5605_11e9_9c4b_80ee73d5e3acrow1_col5" class="data row1 col5" >100</td>
#                         <td id="T_da4233c6_5605_11e9_9c4b_80ee73d5e3acrow1_col6" class="data row1 col6" >0.1</td>
#                         <td id="T_da4233c6_5605_11e9_9c4b_80ee73d5e3acrow1_col7" class="data row1 col7" >22</td>
#                         <td id="T_da4233c6_5605_11e9_9c4b_80ee73d5e3acrow1_col8" class="data row1 col8" >nan</td>
#                         <td id="T_da4233c6_5605_11e9_9c4b_80ee73d5e3acrow1_col9" class="data row1 col9" >8034</td>
#             </tr>
#             <tr>
#                         <th id="T_da4233c6_5605_11e9_9c4b_80ee73d5e3aclevel0_row2" class="row_heading level0 row2" >Penelope</th>
#                         <td id="T_da4233c6_5605_11e9_9c4b_80ee73d5e3acrow2_col0" class="data row2 col0" >Female</td>
#                         <td id="T_da4233c6_5605_11e9_9c4b_80ee73d5e3acrow2_col1" class="data row2 col1" >White</td>
#                         <td id="T_da4233c6_5605_11e9_9c4b_80ee73d5e3acrow2_col2" class="data row2 col2" >Engineering</td>
#                         <td id="T_da4233c6_5605_11e9_9c4b_80ee73d5e3acrow2_col3" class="data row2 col3" >12</td>
#                         <td id="T_da4233c6_5605_11e9_9c4b_80ee73d5e3acrow2_col4" class="data row2 col4" >60258</td>
#                         <td id="T_da4233c6_5605_11e9_9c4b_80ee73d5e3acrow2_col5" class="data row2 col5" >100</td>
#                         <td id="T_da4233c6_5605_11e9_9c4b_80ee73d5e3acrow2_col6" class="data row2 col6" >0</td>
#                         <td id="T_da4233c6_5605_11e9_9c4b_80ee73d5e3acrow2_col7" class="data row2 col7" >22</td>
#                         <td id="T_da4233c6_5605_11e9_9c4b_80ee73d5e3acrow2_col8" class="data row2 col8" >nan</td>
#                         <td id="T_da4233c6_5605_11e9_9c4b_80ee73d5e3acrow2_col9" class="data row2 col9" >5000</td>
#             </tr>
#             <tr>
#                         <th id="T_da4233c6_5605_11e9_9c4b_80ee73d5e3aclevel0_row3" class="row_heading level0 row3" >Aria</th>
#                         <td id="T_da4233c6_5605_11e9_9c4b_80ee73d5e3acrow3_col0" class="data row3 col0" >Female</td>
#                         <td id="T_da4233c6_5605_11e9_9c4b_80ee73d5e3acrow3_col1" class="data row3 col1" >Black</td>
#                         <td id="T_da4233c6_5605_11e9_9c4b_80ee73d5e3acrow3_col2" class="data row3 col2" >Engineering</td>
#                         <td id="T_da4233c6_5605_11e9_9c4b_80ee73d5e3acrow3_col3" class="data row3 col3" >8</td>
#                         <td id="T_da4233c6_5605_11e9_9c4b_80ee73d5e3acrow3_col4" class="data row3 col4" >43618</td>
#                         <td id="T_da4233c6_5605_11e9_9c4b_80ee73d5e3acrow3_col5" class="data row3 col5" >89</td>
#                         <td id="T_da4233c6_5605_11e9_9c4b_80ee73d5e3acrow3_col6" class="data row3 col6" >0.15</td>
#                         <td id="T_da4233c6_5605_11e9_9c4b_80ee73d5e3acrow3_col7" class="data row3 col7" >22</td>
#                         <td id="T_da4233c6_5605_11e9_9c4b_80ee73d5e3acrow3_col8" class="data row3 col8" >nan</td>
#                         <td id="T_da4233c6_5605_11e9_9c4b_80ee73d5e3acrow3_col9" class="data row3 col9" >11542</td>
#             </tr>
#             <tr>
#                         <th id="T_da4233c6_5605_11e9_9c4b_80ee73d5e3aclevel0_row4" class="row_heading level0 row4" >Sofia</th>
#                         <td id="T_da4233c6_5605_11e9_9c4b_80ee73d5e3acrow4_col0" class="data row4 col0" >Female</td>
#                         <td id="T_da4233c6_5605_11e9_9c4b_80ee73d5e3acrow4_col1" class="data row4 col1" >Black</td>
#                         <td id="T_da4233c6_5605_11e9_9c4b_80ee73d5e3acrow4_col2" class="data row4 col2" >Parks & Recreation</td>
#                         <td id="T_da4233c6_5605_11e9_9c4b_80ee73d5e3acrow

# %% [markdown]
# ## Assigning subsets of data in a Series
# Assigning subsets of pandas Series is a less common operation but happens analogously to a DataFrame.
#
# Let's first select a copy of the **`SALARY`** column from our above DataFrame:

# %%
s = df['SALARY'].copy()
s
# Out:
# Tom         107962
# Niko         30347
# Penelope     60258
# Aria         43618
# Sofia        26125
# Dean         33592
# Zach         37565
# Name: SALARY, dtype: int64

# %% [markdown]
# We didn't have to use the **`copy`** method, but we did so to avoid the **`SettingWithCopy`** warning. This is a common warning when making assignments during subset selection. We will cover what it means and how to avoid it in the next notebook.

# %% [markdown]
# ## Assigning with `.loc` and `.iloc`
# Since Series do not have columns, I don't use *just the indexing operator* with them (unless I am doing boolean selection). It can be used to select rows, but is ambiguous and confusing and therefore I avoid it. All the capability of explicitly selecting particular Series values is provided with **`.loc`** and **`.iloc`**.
#
# Let's change the salary of **`Tom`**, **`Sofia`**, and **`Zach`**.

# %%
s.loc[['Tom', 'Sofia', 'Zach']] = [99999, 39999, 49999]
s
# Out:
# Tom         99999
# Niko        30347
# Penelope    60258
# Aria        43618
# Sofia       39999
# Dean        33592
# Zach        49999
# Name: SALARY, dtype: int64

# %% [markdown]
# ## No styling with Series
# Pandas outputs Series as plain text, so we cannot style them like we do with DataFrames.
#
# However, we can create a function to modify the index by appending '-changed' to the ones that have changed.

# %%
# advanced
def style_diff_series(s, s_orig):
    idx = s.index.where(s == s_orig, s.index + '-changed')
    return s.set_axis(idx, inplace=False)

# %% [markdown]
# Create a copy of our original like we did before:

# %%
s = df['SALARY'].copy()
s_orig = s.copy()

# %% [markdown]
# Apply the changes:

# %%
s.loc[['Tom', 'Sofia', 'Zach']] = [99999, 39999, 49999]

# %% [markdown]
# Add 'changed' to the index:

# %%
style_diff_series(s, s_orig)
# Out:
# Tom-changed      99999
# Niko             30347
# Penelope         60258
# Aria             43618
# Sofia-changed    39999
# Dean             33592
# Zach-changed     49999
# Name: SALARY, dtype: int64

# %% [markdown]
# We can make similar changes using integer location with **`.iloc`**. Here we change every other value.

# %%
s_orig = s.copy()
s.iloc[::2]  = 55555
style_diff_series(s, s_orig)
# Out:
# Tom-changed         55555
# Niko                30347
# Penelope-changed    55555
# Aria                43618
# Sofia-changed       55555
# Dean                33592
# Zach-changed        55555
# Name: SALARY, dtype: int64

# %% [markdown]
# ## Assigning Series with boolean indexing
# We can use boolean indexing to make assignments as well. Using *just the indexing operator* is acceptable here. Let's double all the salaries below 40,000

# %%
s_orig = s.copy()
s[s < 40000] *= 2
style_diff_series(s, s_orig)
# Out:
# Tom             55555
# Niko-changed    60694
# Penelope        55555
# Aria            43618
# Sofia           55555
# Dean-changed    67184
# Zach            55555
# Name: SALARY, dtype: int64

# %% [markdown]
# Both *just the indexing operator* and **`.loc`** work the same when doing boolean indexing on a Series. However, as mentioned in part 2, **`.iloc`** should almost never be used when doing boolean indexing as it's not implemented fully.

# %% [markdown]
# # Summary
#
# * Assignment means using the equal sign to assign a variable on the left-hand side to an expression on the right-hand side
# * New columns are created by passing a string to *just the indexing operator* and setting it equal to either a scalar, a list/array the same length as the DataFrame, or a Series with identical index as the DataFrame
# * There is no output when you make an assignment. You must use an extra line to display the DataFrame/Series
# * Select a specific subset of rows/columns with **`.loc`** or **`.iloc`** and manually assign them value with a list/array.
# * Use the **`style`** attribute to make particular values pop out for visual display
# * You can assign entire columns with **`.loc`** or **`.iloc`** by using the colon, **`:`** for rows
# * A more common operation is to use boolean indexing to select subsets of data before making an assignment
# * Assigning new values to a Series is similar to DataFrames except that we don't use **`.iloc`** for boolean indexing

# %% [markdown]
# # Just the basics of assignment of subsets
# This tutorial covered the simplest and most frequently used assignment of subsets. The next notebook will cover some things NOT to do like **chained indexing** and triggering the **`SettingWithCopy`** warning.
#
# There are also many other ways to create new columns or even add multiple columns at the same time. This notebook again, is just drilling the basics.
#
# # Exercises
# We will continue to use the employee sample DataFrame for all the exercises in this tutorial

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('./employee_sample.csv', index_col=0)
df
# Out:
#           GENDER   RACE          DEPARTMENT  YEARS EXPERIENCE  SALARY
# Tom         Male  White         Engineering                23  107962
# Niko        Male  Black         Engineering                 1   30347
# Penelope  Female  White         Engineering                12   60258
# Aria      Female  Black         Engineering                 8   43618
# Sofia     Female  Black  Parks & Recreation                23   26125
# Dean        Male  Black  Parks & Recreation                 3   33592
# Zach        Male  White  Parks & Recreation                 4   37565

# %%
def style_diff(df, df_orig):
    style = {True: '', 
             False: 'color: red; background-color: yellow'}
    df_style = (df == df_orig).replace(style)
    return df.style.apply(lambda x: df_style, axis=None)

# %% [markdown]
# ### Exercise 1
# <span  style="color:green; font-size:16px"> Create a Series with the index equal to the same values in **`df`** but in a different order. Make the values of the Series integers representing the employee's age ranging somewhere from 20 to 65. Create a new column **`AGE`**. Does the order of the index matter?</span>

# %%
series = pd.Series(data=np.random.randint(low=20, high=65, size=len(df)), index=df.index.values)
#series = pd.Series(np.random.randint(low=20, high=60, size=len(df)))
df['AGE'] = series
df #SIM
# Out:
#           GENDER   RACE          DEPARTMENT  YEARS EXPERIENCE  SALARY  AGE
# Tom         Male  White         Engineering                23  107962   37
# Niko        Male  Black         Engineering                 1   30347   49
# Penelope  Female  White         Engineering                12   60258   51
# Aria      Female  Black         Engineering                 8   43618   42
# Sofia     Female  Black  Parks & Recreation                23   26125   21
# Dean        Male  Black  Parks & Recreation                 3   33592   45
# Zach        Male  White  Parks & Recreation                 4   37565   26

# %% [markdown]
# ### Exercise 2
# <span  style="color:green; font-size:16px"> Create a new column **`BONUS`** equal to 0 for everyone</span>

# %%
df['BONUS'] = 0

# %% [markdown]
# ### Exercise 3
# <span  style="color:green; font-size:16px"> Change the **`BONUS`** column so that everyone with more than 10 years of experience get $10,000. Use the **`style_diff`** function to display the results.</span>

# %%
oldf = df.copy()
df.loc[df['YEARS EXPERIENCE']>10, 'BONUS'] = 10000
style_diff(df, oldf)
# Out:
# <style  type="text/css" >
#     #T_d2a02c7a_5611_11e9_b4ac_80ee73d5e3acrow0_col6 {
#             color:  red;
#              background-color:  yellow;
#         }    #T_d2a02c7a_5611_11e9_b4ac_80ee73d5e3acrow2_col6 {
#             color:  red;
#              background-color:  yellow;
#         }    #T_d2a02c7a_5611_11e9_b4ac_80ee73d5e3acrow4_col6 {
#             color:  red;
#              background-color:  yellow;
#         }</style><table id="T_d2a02c7a_5611_11e9_b4ac_80ee73d5e3ac" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >GENDER</th>        <th class="col_heading level0 col1" >RACE</th>        <th class="col_heading level0 col2" >DEPARTMENT</th>        <th class="col_heading level0 col3" >YEARS EXPERIENCE</th>        <th class="col_heading level0 col4" >SALARY</th>        <th class="col_heading level0 col5" >AGE</th>        <th class="col_heading level0 col6" >BONUS</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d2a02c7a_5611_11e9_b4ac_80ee73d5e3aclevel0_row0" class="row_heading level0 row0" >Tom</th>
#                         <td id="T_d2a02c7a_5611_11e9_b4ac_80ee73d5e3acrow0_col0" class="data row0 col0" >Male</td>
#                         <td id="T_d2a02c7a_5611_11e9_b4ac_80ee73d5e3acrow0_col1" class="data row0 col1" >White</td>
#                         <td id="T_d2a02c7a_5611_11e9_b4ac_80ee73d5e3acrow0_col2" class="data row0 col2" >Engineering</td>
#                         <td id="T_d2a02c7a_5611_11e9_b4ac_80ee73d5e3acrow0_col3" class="data row0 col3" >23</td>
#                         <td id="T_d2a02c7a_5611_11e9_b4ac_80ee73d5e3acrow0_col4" class="data row0 col4" >107962</td>
#                         <td id="T_d2a02c7a_5611_11e9_b4ac_80ee73d5e3acrow0_col5" class="data row0 col5" >37</td>
#                         <td id="T_d2a02c7a_5611_11e9_b4ac_80ee73d5e3acrow0_col6" class="data row0 col6" >10000</td>
#             </tr>
#             <tr>
#                         <th id="T_d2a02c7a_5611_11e9_b4ac_80ee73d5e3aclevel0_row1" class="row_heading level0 row1" >Niko</th>
#                         <td id="T_d2a02c7a_5611_11e9_b4ac_80ee73d5e3acrow1_col0" class="data row1 col0" >Male</td>
#                         <td id="T_d2a02c7a_5611_11e9_b4ac_80ee73d5e3acrow1_col1" class="data row1 col1" >Black</td>
#                         <td id="T_d2a02c7a_5611_11e9_b4ac_80ee73d5e3acrow1_col2" class="data row1 col2" >Engineering</td>
#                         <td id="T_d2a02c7a_5611_11e9_b4ac_80ee73d5e3acrow1_col3" class="data row1 col3" >1</td>
#                         <td id="T_d2a02c7a_5611_11e9_b4ac_80ee73d5e3acrow1_col4" class="data row1 col4" >30347</td>
#                         <td id="T_d2a02c7a_5611_11e9_b4ac_80ee73d5e3acrow1_col5" class="data row1 col5" >49</td>
#                         <td id="T_d2a02c7a_5611_11e9_b4ac_80ee73d5e3acrow1_col6" class="data row1 col6" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_d2a02c7a_5611_11e9_b4ac_80ee73d5e3aclevel0_row2" class="row_heading level0 row2" >Penelope</th>
#                         <td id="T_d2a02c7a_5611_11e9_b4ac_80ee73d5e3acrow2_col0" class="data row2 col0" >Female</td>
#                         <td id="T_d2a02c7a_5611_11e9_b4ac_80ee73d5e3acrow2_col1" class="data row2 col1" >White</td>
#                         <td id="T_d2a02c7a_5611_11e9_b4ac_80ee73d5e3acrow2_col2" class="data row2 col2" >Engineering</td>
#                         <td id="T_d2a02c7a_5611_11e9_b4ac_80ee73d5e3acrow2_col3" class="data row2 col3" >12</td>
#                         <td id="T_d2a02c7a_5611_11e9_b4ac_80ee73d5e3acrow2_col4" class="data row2 col4" >60258</td>
#                         <td id="T_d2a02c7a_5611_11e9_b4ac_80ee73d5e3acrow2_col5" class="data row2 col5" >51</td>
#                         <td id="T_d2a02c7a_5611_11e9_b4ac_80ee73d5e3acrow2_col6" class="data row2 col6" >10000</td>
#             </tr>
#             <tr>
#                         <th id="T_d2a02c7a_5611_11e9_b4ac_80ee73d5e3aclevel0_row3" class="row_heading level0 row3" >Aria</th>
#                         <td id="T_d2a02c7a_5611_11e9_b4ac_80ee73d5e3acrow3_col0" class="data row3 col0" >Female</td>
#                         <td id="T_d2a02c7a_5611_11e9_b4ac_80ee73d5e3acrow3_col1" class="data row3 col1" >Black</td>
#                         <td id="T_d2a02c7a_5611_11e9_b4ac_80ee73d5e3acrow3_col2" class="data row3 col2" >Engineering</td>
#                         <td id="T_d2a02c7a_5611_11e9_b4ac_80ee73d5e3acrow3_col3" class="data row3 col3" >8</td>
#                         <td id="T_d2a02c7a_5611_11e9_b4ac_80ee73d5e3acrow3_col4" class="data row3 col4" >43618</td>
#                         <td id="T_d2a02c7a_5611_11e9_b4ac_80ee73d5e3acrow3_col5" class="data row3 col5" >42</td>
#                         <td id="T_d2a02c7a_5611_11e9_b4ac_80ee73d5e3acrow3_col6" class="data row3 col6" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_d2a02c7a_5611_11e9_b4ac_80ee73d5e3aclevel0_row4" class="row_heading level0 row4" >Sofia</th>
#                         <td id="T_d2a02c7a_5611_11e9_b4ac_80ee73d5e3acrow4_col0" class="data row4 col0" >Female</td>
#                         <td id="T_d2a02c7a_5611_11e9_b4ac_80ee73d5e3acrow4_col1" class="data row4 col1" >Black</td>
#                         <td id="T_d2a02c7a_5611_11e9_b4ac_80ee73d5e3acrow4_col2" class="data row4 col2" >Parks & Recreation</td>
#                         <td id="T_d2a02c7a_5611_11e9_b4ac_80ee73d5e3acrow4_col3" class="data row4 col3" >23</td>
#                         <td id="T_d2a02c7a_5611_11e9_b4ac_80ee73d5e3acrow4_col4" class="data row4 col4" >26125</td>
#                         <td id="T_d2a02c7a_5611_11e9_b4ac_80ee73d5e3acrow4_col5" class="data row4 col5" >21</td>
#                         <td id="T_d2a02c7a_5611_11e9_b4ac_80ee73d5e3acrow4_col6" class="data row4 col6" >10000</td>
#             </tr>
#             <tr>
#                         <th id="T_d2a02c7a_5611_11e9_b4ac_80ee73d5e3aclevel0_row5" class="row_heading level0 row5" >Dean</th>
#                         <td id="T_d2a02c7a_5611_11e9_b4ac_80ee73d5e3acrow5_col0" class="data row5 col0" >Male</td>
#                         <td id="T_d2a02c7a_5611_11e9_b4ac_80ee73d5e3acrow5_col1" class="data row5 col1" >Black</td>
#                         <td id="T_d2a02c7a_5611_11e9_b4ac_80ee73d5e3acrow5_col2" class="data row5 col2" >Parks & Recreation</td>
#                         <td id="T_d2a02c7a_5611_11e9_b4ac_80ee73d5e3acrow5_col3" class="data row5 col3" >3</td>
#                         <td id="T_d2a02c7a_5611_11e9_b4ac_80ee73d5e3acrow5_col4" class="data row5 col4" >33592</td>
#                         <td id="T_d2a02c7a_5611_11e9_b4ac_80ee73d5e3acrow5_col5" class="data row5 col5" >45</td>
#                         <td id="T_d2a02c7a_5611_11e9_b4ac_80ee73d5e3acrow5_col6" class="data row5 col6" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_d2a02c7a_5611_11e9_b4ac_80ee73d5e3aclevel0_row6" class="row_heading level0 row6" >Zach</th>
#                         <td id="T_d2a02c7a_5611_11e9_b4ac_80ee73d5e3acrow6_col0" class="data row6 col0" >Male</td>
#                         <td id="T_d2a02c7a_5611_11e9_b4ac_80ee73d5e3acrow6_col1" class="data row6 col1" >White</td>
#                         <td id="T_d2a02c7a_5611_11e9_b4ac_80ee73d5e3acrow6_col2" class="data row6 col2" >Parks & Recreation</td>
#                         <td id="T_d2a02c7a_5611_11e9_b4ac_80ee73d5e3acrow6_col3" class="data row6 col3" >4</td>
#                         <td id="T_d2a02c7a_5611_11e9_b4ac_80ee73d5e3acrow6_col4" class="data row6 col4" >37565</td>
#                         <td id="T_d2a02c7a_5611_11e9_b4ac_80ee73d5e3acrow6_col5" class="data row6 col5" >26</td>
#                         <td id="T_d2a02c7a_5611_11e9_b4ac_80ee73d5e3acrow6_col6" class="data row6 col6" >0</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ### Exercise 4
# <span  style="color:green; font-size:16px"> Create a new column **`TOTAL SALARY`** that is 10% higher than the current **`SALARY`** column and add the bonus on top of that as well. Use **`.loc`** on the left-hand side and NOT *just the indexing operator*. Make the data type **`TOTAL SALARY`** an integer.</span>

# %%
df.loc[:,'TOTAL SALARY'] = df.loc[:, 'SALARY']*1.1 + df.loc[:, 'BONUS']
df.loc[:,'TOTAL SALARY'] = df.loc[:,'TOTAL SALARY'].astype(int)
df
# Out:
#           GENDER   RACE          DEPARTMENT  YEARS EXPERIENCE  SALARY  AGE  \
# Tom         Male  White         Engineering                23  107962   37
# Niko        Male  Black         Engineering                 1   30347   49
# Penelope  Female  White         Engineering                12   60258   51
# Aria      Female  Black         Engineering                 8   43618   42
# Sofia     Female  Black  Parks & Recreation                23   26125   21
# Dean        Male  Black  Parks & Recreation                 3   33592   45
# Zach        Male  White  Parks & Recreation                 4   37565   26
#
#           BONUS  TOTAL SALARY
# Tom       10000        128758
# Niko          0         33381
# Penelope  10000         76283
# Aria          0         47979
# Sofia     10000         38737
# Dean          0         36951
# Zach          0         41321

# %% [markdown]
# ### Exercise 5
# <span  style="color:green; font-size:16px"> Set Aria's department to 'Police'. Highlight the change</span>

# %%
oldf = df.copy()
df.loc['Aria', 'DEPARTMENT'] = 'Police'
style_diff(df, oldf)
# Out:
# <style  type="text/css" >
#     #T_1f792d34_5612_11e9_a357_80ee73d5e3acrow3_col2 {
#             color:  red;
#              background-color:  yellow;
#         }</style><table id="T_1f792d34_5612_11e9_a357_80ee73d5e3ac" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >GENDER</th>        <th class="col_heading level0 col1" >RACE</th>        <th class="col_heading level0 col2" >DEPARTMENT</th>        <th class="col_heading level0 col3" >YEARS EXPERIENCE</th>        <th class="col_heading level0 col4" >SALARY</th>        <th class="col_heading level0 col5" >AGE</th>        <th class="col_heading level0 col6" >BONUS</th>        <th class="col_heading level0 col7" >TOTAL SALARY</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1f792d34_5612_11e9_a357_80ee73d5e3aclevel0_row0" class="row_heading level0 row0" >Tom</th>
#                         <td id="T_1f792d34_5612_11e9_a357_80ee73d5e3acrow0_col0" class="data row0 col0" >Male</td>
#                         <td id="T_1f792d34_5612_11e9_a357_80ee73d5e3acrow0_col1" class="data row0 col1" >White</td>
#                         <td id="T_1f792d34_5612_11e9_a357_80ee73d5e3acrow0_col2" class="data row0 col2" >Engineering</td>
#                         <td id="T_1f792d34_5612_11e9_a357_80ee73d5e3acrow0_col3" class="data row0 col3" >23</td>
#                         <td id="T_1f792d34_5612_11e9_a357_80ee73d5e3acrow0_col4" class="data row0 col4" >107962</td>
#                         <td id="T_1f792d34_5612_11e9_a357_80ee73d5e3acrow0_col5" class="data row0 col5" >37</td>
#                         <td id="T_1f792d34_5612_11e9_a357_80ee73d5e3acrow0_col6" class="data row0 col6" >10000</td>
#                         <td id="T_1f792d34_5612_11e9_a357_80ee73d5e3acrow0_col7" class="data row0 col7" >128758</td>
#             </tr>
#             <tr>
#                         <th id="T_1f792d34_5612_11e9_a357_80ee73d5e3aclevel0_row1" class="row_heading level0 row1" >Niko</th>
#                         <td id="T_1f792d34_5612_11e9_a357_80ee73d5e3acrow1_col0" class="data row1 col0" >Male</td>
#                         <td id="T_1f792d34_5612_11e9_a357_80ee73d5e3acrow1_col1" class="data row1 col1" >Black</td>
#                         <td id="T_1f792d34_5612_11e9_a357_80ee73d5e3acrow1_col2" class="data row1 col2" >Engineering</td>
#                         <td id="T_1f792d34_5612_11e9_a357_80ee73d5e3acrow1_col3" class="data row1 col3" >1</td>
#                         <td id="T_1f792d34_5612_11e9_a357_80ee73d5e3acrow1_col4" class="data row1 col4" >30347</td>
#                         <td id="T_1f792d34_5612_11e9_a357_80ee73d5e3acrow1_col5" class="data row1 col5" >49</td>
#                         <td id="T_1f792d34_5612_11e9_a357_80ee73d5e3acrow1_col6" class="data row1 col6" >0</td>
#                         <td id="T_1f792d34_5612_11e9_a357_80ee73d5e3acrow1_col7" class="data row1 col7" >33381</td>
#             </tr>
#             <tr>
#                         <th id="T_1f792d34_5612_11e9_a357_80ee73d5e3aclevel0_row2" class="row_heading level0 row2" >Penelope</th>
#                         <td id="T_1f792d34_5612_11e9_a357_80ee73d5e3acrow2_col0" class="data row2 col0" >Female</td>
#                         <td id="T_1f792d34_5612_11e9_a357_80ee73d5e3acrow2_col1" class="data row2 col1" >White</td>
#                         <td id="T_1f792d34_5612_11e9_a357_80ee73d5e3acrow2_col2" class="data row2 col2" >Engineering</td>
#                         <td id="T_1f792d34_5612_11e9_a357_80ee73d5e3acrow2_col3" class="data row2 col3" >12</td>
#                         <td id="T_1f792d34_5612_11e9_a357_80ee73d5e3acrow2_col4" class="data row2 col4" >60258</td>
#                         <td id="T_1f792d34_5612_11e9_a357_80ee73d5e3acrow2_col5" class="data row2 col5" >51</td>
#                         <td id="T_1f792d34_5612_11e9_a357_80ee73d5e3acrow2_col6" class="data row2 col6" >10000</td>
#                         <td id="T_1f792d34_5612_11e9_a357_80ee73d5e3acrow2_col7" class="data row2 col7" >76283</td>
#             </tr>
#             <tr>
#                         <th id="T_1f792d34_5612_11e9_a357_80ee73d5e3aclevel0_row3" class="row_heading level0 row3" >Aria</th>
#                         <td id="T_1f792d34_5612_11e9_a357_80ee73d5e3acrow3_col0" class="data row3 col0" >Female</td>
#                         <td id="T_1f792d34_5612_11e9_a357_80ee73d5e3acrow3_col1" class="data row3 col1" >Black</td>
#                         <td id="T_1f792d34_5612_11e9_a357_80ee73d5e3acrow3_col2" class="data row3 col2" >Police</td>
#                         <td id="T_1f792d34_5612_11e9_a357_80ee73d5e3acrow3_col3" class="data row3 col3" >8</td>
#                         <td id="T_1f792d34_5612_11e9_a357_80ee73d5e3acrow3_col4" class="data row3 col4" >43618</td>
#                         <td id="T_1f792d34_5612_11e9_a357_80ee73d5e3acrow3_col5" class="data row3 col5" >42</td>
#                         <td id="T_1f792d34_5612_11e9_a357_80ee73d5e3acrow3_col6" class="data row3 col6" >0</td>
#                         <td id="T_1f792d34_5612_11e9_a357_80ee73d5e3acrow3_col7" class="data row3 col7" >47979</td>
#             </tr>
#             <tr>
#                         <th id="T_1f792d34_5612_11e9_a357_80ee73d5e3aclevel0_row4" class="row_heading level0 row4" >Sofia</th>
#                         <td id="T_1f792d34_5612_11e9_a357_80ee73d5e3acrow4_col0" class="data row4 col0" >Female</td>
#                         <td id="T_1f792d34_5612_11e9_a357_80ee73d5e3acrow4_col1" class="data row4 col1" >Black</td>
#                         <td id="T_1f792d34_5612_11e9_a357_80ee73d5e3acrow4_col2" class="data row4 col2" >Parks & Recreation</td>
#                         <td id="T_1f792d34_5612_11e9_a357_80ee73d5e3acrow4_col3" class="data row4 col3" >23</td>
#                         <td id="T_1f792d34_5612_11e9_a357_80ee73d5e3acrow4_col4" class="data row4 col4" >26125</td>
#                         <td id="T_1f792d34_5612_11e9_a357_80ee73d5e3acrow4_col5" class="data row4 col5" >21</td>
#                         <td id="T_1f792d34_5612_11e9_a357_80ee73d5e3acrow4_col6" class="data row4 col6" >10000</td>
#                         <td id="T_1f792d34_5612_11e9_a357_80ee73d5e3acrow4_col7" class="data row4 col7" >38737</td>
#             </tr>
#             <tr>
#                         <th id="T_1f792d34_5612_11e9_a357_80ee73d5e3aclevel0_row5" class="row_heading level0 row5" >Dean</th>
#                         <td id="T_1f792d34_5612_11e9_a357_80ee73d5e3acrow5_col0" class="data row5 col0" >Male</td>
#                         <td id="T_1f792d34_5612_11e9_a357_80ee73d5e3acrow5_col1" class="data row5 col1" >Black</td>
#                         <td id="T_1f792d34_5612_11e9_a357_80ee73d5e3acrow5_col2" class="data row5 col2" >Parks & Recreation</td>
#                         <td id="T_1f792d34_5612_11e9_a357_80ee73d5e3acrow5_col3" class="data row5 col3" >3</td>
#                         <td id="T_1f792d34_5612_11e9_a357_80ee73d5e3acrow5_col4" class="data row5 col4" >33592</td>
#                         <td id="T_1f792d34_5612_11e9_a357_80ee73d5e3acrow5_col5" class="data row5 col5" >45</td>
#                         <td id="T_1f792d34_5612_11e9_a357_80ee73d5e3acrow5_col6" class="data row5 col6" >0</td>
#                         <td id="T_1f792d34_5612_11e9_a357_80ee73d5e3acrow5_col7" class="data row5 col7" >36951</td>
#             </tr>
#             <tr>
#                         <th id="T_1f792d34_5612_11e9_a357_80ee73d5e3aclevel0_row6" class="row_heading level0 row6" >Zach</th>
#                         <td id="T_1f792d34_5612_11e9_a357_80ee73d5e3acrow6_col0" class="data row6 col0" >Male</td>
#                         <td id="T_1f792d34_5612_11e9_a357_80ee73d5e3acrow6_col1" class="data row6 col1" >White</td>
#                         <td id="T_1f792d34_5612_11e9_a357_80ee73d5e3acrow6_col2" class="data row6 col2" >Parks & Recreation</td>
#                         <td id="T_1f792d34_5612_11e9_a357_80ee73d5e3acrow6_col3" class="data row6 col3" >4</td>
#                         <td id="T_1f792d34_5612_11e9_a357_80ee73d5e3acrow6_col4" class="dat

# %% [markdown]
# ### Exercise 6
# <span  style="color:green; font-size:16px"> Give all the white engineers a salary raise of \$10,000 and all the black Parks & Recreation employees a decrease in salary by \$10,000. Highlight the change.</span>

# %%
oldf = df.copy()
criteria = (df['RACE'] ==  'White') & (df['DEPARTMENT'] == 'Engineering')
df.loc[criteria, 'SALARY'] = df.loc[criteria]['SALARY'] + 10000
criteria = (df['RACE'] ==  'Black') & (df['DEPARTMENT'] == 'Parks & Recreation')
df.loc[criteria, 'SALARY'] = df.loc[criteria]['SALARY'] - 10000
style_diff(df, oldf)
# Out:
# <style  type="text/css" >
#     #T_e13f2db6_5613_11e9_845f_80ee73d5e3acrow0_col4 {
#             color:  red;
#              background-color:  yellow;
#         }    #T_e13f2db6_5613_11e9_845f_80ee73d5e3acrow2_col4 {
#             color:  red;
#              background-color:  yellow;
#         }    #T_e13f2db6_5613_11e9_845f_80ee73d5e3acrow4_col4 {
#             color:  red;
#              background-color:  yellow;
#         }    #T_e13f2db6_5613_11e9_845f_80ee73d5e3acrow5_col4 {
#             color:  red;
#              background-color:  yellow;
#         }</style><table id="T_e13f2db6_5613_11e9_845f_80ee73d5e3ac" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >GENDER</th>        <th class="col_heading level0 col1" >RACE</th>        <th class="col_heading level0 col2" >DEPARTMENT</th>        <th class="col_heading level0 col3" >YEARS EXPERIENCE</th>        <th class="col_heading level0 col4" >SALARY</th>        <th class="col_heading level0 col5" >AGE</th>        <th class="col_heading level0 col6" >BONUS</th>        <th class="col_heading level0 col7" >TOTAL SALARY</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e13f2db6_5613_11e9_845f_80ee73d5e3aclevel0_row0" class="row_heading level0 row0" >Tom</th>
#                         <td id="T_e13f2db6_5613_11e9_845f_80ee73d5e3acrow0_col0" class="data row0 col0" >Male</td>
#                         <td id="T_e13f2db6_5613_11e9_845f_80ee73d5e3acrow0_col1" class="data row0 col1" >White</td>
#                         <td id="T_e13f2db6_5613_11e9_845f_80ee73d5e3acrow0_col2" class="data row0 col2" >Engineering</td>
#                         <td id="T_e13f2db6_5613_11e9_845f_80ee73d5e3acrow0_col3" class="data row0 col3" >23</td>
#                         <td id="T_e13f2db6_5613_11e9_845f_80ee73d5e3acrow0_col4" class="data row0 col4" >137962</td>
#                         <td id="T_e13f2db6_5613_11e9_845f_80ee73d5e3acrow0_col5" class="data row0 col5" >37</td>
#                         <td id="T_e13f2db6_5613_11e9_845f_80ee73d5e3acrow0_col6" class="data row0 col6" >10000</td>
#                         <td id="T_e13f2db6_5613_11e9_845f_80ee73d5e3acrow0_col7" class="data row0 col7" >128758</td>
#             </tr>
#             <tr>
#                         <th id="T_e13f2db6_5613_11e9_845f_80ee73d5e3aclevel0_row1" class="row_heading level0 row1" >Niko</th>
#                         <td id="T_e13f2db6_5613_11e9_845f_80ee73d5e3acrow1_col0" class="data row1 col0" >Male</td>
#                         <td id="T_e13f2db6_5613_11e9_845f_80ee73d5e3acrow1_col1" class="data row1 col1" >Black</td>
#                         <td id="T_e13f2db6_5613_11e9_845f_80ee73d5e3acrow1_col2" class="data row1 col2" >Engineering</td>
#                         <td id="T_e13f2db6_5613_11e9_845f_80ee73d5e3acrow1_col3" class="data row1 col3" >1</td>
#                         <td id="T_e13f2db6_5613_11e9_845f_80ee73d5e3acrow1_col4" class="data row1 col4" >30347</td>
#                         <td id="T_e13f2db6_5613_11e9_845f_80ee73d5e3acrow1_col5" class="data row1 col5" >49</td>
#                         <td id="T_e13f2db6_5613_11e9_845f_80ee73d5e3acrow1_col6" class="data row1 col6" >0</td>
#                         <td id="T_e13f2db6_5613_11e9_845f_80ee73d5e3acrow1_col7" class="data row1 col7" >33381</td>
#             </tr>
#             <tr>
#                         <th id="T_e13f2db6_5613_11e9_845f_80ee73d5e3aclevel0_row2" class="row_heading level0 row2" >Penelope</th>
#                         <td id="T_e13f2db6_5613_11e9_845f_80ee73d5e3acrow2_col0" class="data row2 col0" >Female</td>
#                         <td id="T_e13f2db6_5613_11e9_845f_80ee73d5e3acrow2_col1" class="data row2 col1" >White</td>
#                         <td id="T_e13f2db6_5613_11e9_845f_80ee73d5e3acrow2_col2" class="data row2 col2" >Engineering</td>
#                         <td id="T_e13f2db6_5613_11e9_845f_80ee73d5e3acrow2_col3" class="data row2 col3" >12</td>
#                         <td id="T_e13f2db6_5613_11e9_845f_80ee73d5e3acrow2_col4" class="data row2 col4" >90258</td>
#                         <td id="T_e13f2db6_5613_11e9_845f_80ee73d5e3acrow2_col5" class="data row2 col5" >51</td>
#                         <td id="T_e13f2db6_5613_11e9_845f_80ee73d5e3acrow2_col6" class="data row2 col6" >10000</td>
#                         <td id="T_e13f2db6_5613_11e9_845f_80ee73d5e3acrow2_col7" class="data row2 col7" >76283</td>
#             </tr>
#             <tr>
#                         <th id="T_e13f2db6_5613_11e9_845f_80ee73d5e3aclevel0_row3" class="row_heading level0 row3" >Aria</th>
#                         <td id="T_e13f2db6_5613_11e9_845f_80ee73d5e3acrow3_col0" class="data row3 col0" >Female</td>
#                         <td id="T_e13f2db6_5613_11e9_845f_80ee73d5e3acrow3_col1" class="data row3 col1" >Black</td>
#                         <td id="T_e13f2db6_5613_11e9_845f_80ee73d5e3acrow3_col2" class="data row3 col2" >Police</td>
#                         <td id="T_e13f2db6_5613_11e9_845f_80ee73d5e3acrow3_col3" class="data row3 col3" >8</td>
#                         <td id="T_e13f2db6_5613_11e9_845f_80ee73d5e3acrow3_col4" class="data row3 col4" >43618</td>
#                         <td id="T_e13f2db6_5613_11e9_845f_80ee73d5e3acrow3_col5" class="data row3 col5" >42</td>
#                         <td id="T_e13f2db6_5613_11e9_845f_80ee73d5e3acrow3_col6" class="data row3 col6" >0</td>
#                         <td id="T_e13f2db6_5613_11e9_845f_80ee73d5e3acrow3_col7" class="data row3 col7" >47979</td>
#             </tr>
#             <tr>
#                         <th id="T_e13f2db6_5613_11e9_845f_80ee73d5e3aclevel0_row4" class="row_heading level0 row4" >Sofia</th>
#                         <td id="T_e13f2db6_5613_11e9_845f_80ee73d5e3acrow4_col0" class="data row4 col0" >Female</td>
#                         <td id="T_e13f2db6_5613_11e9_845f_80ee73d5e3acrow4_col1" class="data row4 col1" >Black</td>
#                         <td id="T_e13f2db6_5613_11e9_845f_80ee73d5e3acrow4_col2" class="data row4 col2" >Parks & Recreation</td>
#                         <td id="T_e13f2db6_5613_11e9_845f_80ee73d5e3acrow4_col3" class="data row4 col3" >23</td>
#                         <td id="T_e13f2db6_5613_11e9_845f_80ee73d5e3acrow4_col4" class="data row4 col4" >16125</td>
#                         <td id="T_e13f2db6_5613_11e9_845f_80ee73d5e3acrow4_col5" class="data row4 col5" >21</td>
#                         <td id="T_e13f2db6_5613_11e9_845f_80ee73d5e3acrow4_col6" class="data row4 col6" >10000</td>
#                         <td id="T_e13f2db6_5613_11e9_845f_80ee73d5e3acrow4_col7" class="data row4 col7" >38737</td>
#             </tr>
#             <tr>
#                         <th id="T_e13f2db6_5613_11e9_845f_80ee73d5e3aclevel0_row5" class="row_heading level0 row5" >Dean</th>
#                         <td id="T_e13f2db6_5613_11e9_845f_80ee73d5e3acrow5_col0" class="data row5 col0" >Male</td>
#                         <td id="T_e13f2db6_5613_11e9_845f_80ee73d5e3acrow5_col1" class="data row5 col1" >Black</td>
#                         <td id="T_e13f2db6_5613_11e9_845f_80ee73d5e3acrow5_col2" class="data row5 col2" >Parks & Recreation</td>
#                         <td id="T_e13f2db6_5613_11e9_845f_80ee73d5e3acrow5_col3" class="data row5 col3" >3</td>
#                         <td id="T_e13f2db6_5613_11e9_845f_80ee73d5e3acrow5_col4" class="data row5 col4" >23592</td>
#                         <td id="T_e13f2db6_5613_11e9_845f_80ee73d5e3acrow5_col5" class="data row5 col5" >45</td>
#                         <td id="T_e13f2db6_5613_11e9_845f_80ee73d5e3acrow5_col6" class="data row5 col6" >0</td>
#                         <td id="T_e13f2db6_5613_11e9_845f_80ee73d5e3acrow5_col7" class="data row5 col7" >36951</td>
#             </tr>
#             <tr>
#                         <th id="T_e13f2db6_5613_11e9_845f_80ee73d5e3aclevel0_row6" class="row_heading level0 row6" >Zach</th>
#                         <td id="T_e13f2db6_5613_11e9_845f_80ee73d5e3acrow6_col0" class="data row6 col0" >Male</td>
#                         <td id="T_e13f2db6_5613_11e9_845f_80e

# %% [markdown]
# ### Exercise 7
# <span  style="color:green; font-size:16px"> Use **`.iloc`** to change the age of the employees with integer location 3 and 5 to 60 and 65 respectively. Highlight the change.</span>

# %%
oldf = df.copy()
df.iloc[[3,5], -3]  = [60, 65]
style_diff(df, oldf)
# Out:
# <style  type="text/css" >
#     #T_a430cbfa_5614_11e9_b891_80ee73d5e3acrow3_col5 {
#             color:  red;
#              background-color:  yellow;
#         }    #T_a430cbfa_5614_11e9_b891_80ee73d5e3acrow5_col5 {
#             color:  red;
#              background-color:  yellow;
#         }</style><table id="T_a430cbfa_5614_11e9_b891_80ee73d5e3ac" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >GENDER</th>        <th class="col_heading level0 col1" >RACE</th>        <th class="col_heading level0 col2" >DEPARTMENT</th>        <th class="col_heading level0 col3" >YEARS EXPERIENCE</th>        <th class="col_heading level0 col4" >SALARY</th>        <th class="col_heading level0 col5" >AGE</th>        <th class="col_heading level0 col6" >BONUS</th>        <th class="col_heading level0 col7" >TOTAL SALARY</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a430cbfa_5614_11e9_b891_80ee73d5e3aclevel0_row0" class="row_heading level0 row0" >Tom</th>
#                         <td id="T_a430cbfa_5614_11e9_b891_80ee73d5e3acrow0_col0" class="data row0 col0" >Male</td>
#                         <td id="T_a430cbfa_5614_11e9_b891_80ee73d5e3acrow0_col1" class="data row0 col1" >White</td>
#                         <td id="T_a430cbfa_5614_11e9_b891_80ee73d5e3acrow0_col2" class="data row0 col2" >Engineering</td>
#                         <td id="T_a430cbfa_5614_11e9_b891_80ee73d5e3acrow0_col3" class="data row0 col3" >23</td>
#                         <td id="T_a430cbfa_5614_11e9_b891_80ee73d5e3acrow0_col4" class="data row0 col4" >137962</td>
#                         <td id="T_a430cbfa_5614_11e9_b891_80ee73d5e3acrow0_col5" class="data row0 col5" >37</td>
#                         <td id="T_a430cbfa_5614_11e9_b891_80ee73d5e3acrow0_col6" class="data row0 col6" >10000</td>
#                         <td id="T_a430cbfa_5614_11e9_b891_80ee73d5e3acrow0_col7" class="data row0 col7" >128758</td>
#             </tr>
#             <tr>
#                         <th id="T_a430cbfa_5614_11e9_b891_80ee73d5e3aclevel0_row1" class="row_heading level0 row1" >Niko</th>
#                         <td id="T_a430cbfa_5614_11e9_b891_80ee73d5e3acrow1_col0" class="data row1 col0" >Male</td>
#                         <td id="T_a430cbfa_5614_11e9_b891_80ee73d5e3acrow1_col1" class="data row1 col1" >Black</td>
#                         <td id="T_a430cbfa_5614_11e9_b891_80ee73d5e3acrow1_col2" class="data row1 col2" >Engineering</td>
#                         <td id="T_a430cbfa_5614_11e9_b891_80ee73d5e3acrow1_col3" class="data row1 col3" >1</td>
#                         <td id="T_a430cbfa_5614_11e9_b891_80ee73d5e3acrow1_col4" class="data row1 col4" >30347</td>
#                         <td id="T_a430cbfa_5614_11e9_b891_80ee73d5e3acrow1_col5" class="data row1 col5" >49</td>
#                         <td id="T_a430cbfa_5614_11e9_b891_80ee73d5e3acrow1_col6" class="data row1 col6" >0</td>
#                         <td id="T_a430cbfa_5614_11e9_b891_80ee73d5e3acrow1_col7" class="data row1 col7" >33381</td>
#             </tr>
#             <tr>
#                         <th id="T_a430cbfa_5614_11e9_b891_80ee73d5e3aclevel0_row2" class="row_heading level0 row2" >Penelope</th>
#                         <td id="T_a430cbfa_5614_11e9_b891_80ee73d5e3acrow2_col0" class="data row2 col0" >Female</td>
#                         <td id="T_a430cbfa_5614_11e9_b891_80ee73d5e3acrow2_col1" class="data row2 col1" >White</td>
#                         <td id="T_a430cbfa_5614_11e9_b891_80ee73d5e3acrow2_col2" class="data row2 col2" >Engineering</td>
#                         <td id="T_a430cbfa_5614_11e9_b891_80ee73d5e3acrow2_col3" class="data row2 col3" >12</td>
#                         <td id="T_a430cbfa_5614_11e9_b891_80ee73d5e3acrow2_col4" class="data row2 col4" >90258</td>
#                         <td id="T_a430cbfa_5614_11e9_b891_80ee73d5e3acrow2_col5" class="data row2 col5" >51</td>
#                         <td id="T_a430cbfa_5614_11e9_b891_80ee73d5e3acrow2_col6" class="data row2 col6" >10000</td>
#                         <td id="T_a430cbfa_5614_11e9_b891_80ee73d5e3acrow2_col7" class="data row2 col7" >76283</td>
#             </tr>
#             <tr>
#                         <th id="T_a430cbfa_5614_11e9_b891_80ee73d5e3aclevel0_row3" class="row_heading level0 row3" >Aria</th>
#                         <td id="T_a430cbfa_5614_11e9_b891_80ee73d5e3acrow3_col0" class="data row3 col0" >Female</td>
#                         <td id="T_a430cbfa_5614_11e9_b891_80ee73d5e3acrow3_col1" class="data row3 col1" >Black</td>
#                         <td id="T_a430cbfa_5614_11e9_b891_80ee73d5e3acrow3_col2" class="data row3 col2" >Police</td>
#                         <td id="T_a430cbfa_5614_11e9_b891_80ee73d5e3acrow3_col3" class="data row3 col3" >8</td>
#                         <td id="T_a430cbfa_5614_11e9_b891_80ee73d5e3acrow3_col4" class="data row3 col4" >43618</td>
#                         <td id="T_a430cbfa_5614_11e9_b891_80ee73d5e3acrow3_col5" class="data row3 col5" >60</td>
#                         <td id="T_a430cbfa_5614_11e9_b891_80ee73d5e3acrow3_col6" class="data row3 col6" >0</td>
#                         <td id="T_a430cbfa_5614_11e9_b891_80ee73d5e3acrow3_col7" class="data row3 col7" >47979</td>
#             </tr>
#             <tr>
#                         <th id="T_a430cbfa_5614_11e9_b891_80ee73d5e3aclevel0_row4" class="row_heading level0 row4" >Sofia</th>
#                         <td id="T_a430cbfa_5614_11e9_b891_80ee73d5e3acrow4_col0" class="data row4 col0" >Female</td>
#                         <td id="T_a430cbfa_5614_11e9_b891_80ee73d5e3acrow4_col1" class="data row4 col1" >Black</td>
#                         <td id="T_a430cbfa_5614_11e9_b891_80ee73d5e3acrow4_col2" class="data row4 col2" >Parks & Recreation</td>
#                         <td id="T_a430cbfa_5614_11e9_b891_80ee73d5e3acrow4_col3" class="data row4 col3" >23</td>
#                         <td id="T_a430cbfa_5614_11e9_b891_80ee73d5e3acrow4_col4" class="data row4 col4" >16125</td>
#                         <td id="T_a430cbfa_5614_11e9_b891_80ee73d5e3acrow4_col5" class="data row4 col5" >21</td>
#                         <td id="T_a430cbfa_5614_11e9_b891_80ee73d5e3acrow4_col6" class="data row4 col6" >10000</td>
#                         <td id="T_a430cbfa_5614_11e9_b891_80ee73d5e3acrow4_col7" class="data row4 col7" >38737</td>
#             </tr>
#             <tr>
#                         <th id="T_a430cbfa_5614_11e9_b891_80ee73d5e3aclevel0_row5" class="row_heading level0 row5" >Dean</th>
#                         <td id="T_a430cbfa_5614_11e9_b891_80ee73d5e3acrow5_col0" class="data row5 col0" >Male</td>
#                         <td id="T_a430cbfa_5614_11e9_b891_80ee73d5e3acrow5_col1" class="data row5 col1" >Black</td>
#                         <td id="T_a430cbfa_5614_11e9_b891_80ee73d5e3acrow5_col2" class="data row5 col2" >Parks & Recreation</td>
#                         <td id="T_a430cbfa_5614_11e9_b891_80ee73d5e3acrow5_col3" class="data row5 col3" >3</td>
#                         <td id="T_a430cbfa_5614_11e9_b891_80ee73d5e3acrow5_col4" class="data row5 col4" >23592</td>
#                         <td id="T_a430cbfa_5614_11e9_b891_80ee73d5e3acrow5_col5" class="data row5 col5" >65</td>
#                         <td id="T_a430cbfa_5614_11e9_b891_80ee73d5e3acrow5_col6" class="data row5 col6" >0</td>
#                         <td id="T_a430cbfa_5614_11e9_b891_80ee73d5e3acrow5_col7" class="data row5 col7" >36951</td>
#             </tr>
#             <tr>
#                         <th id="T_a430cbfa_5614_11e9_b891_80ee73d5e3aclevel0_row6" class="row_heading level0 row6" >Zach</th>
#                         <td id="T_a430cbfa_5614_11e9_b891_80ee73d5e3acrow6_col0" class="data row6 col0" >Male</td>
#                         <td id="T_a430cbfa_5614_11e9_b891_80ee73d5e3acrow6_col1" class="data row6 col1" >White</td>
#                         <td id="T_a430cbfa_5614_11e9_b891_80ee73d5e3acrow6_col2" class="data row6 col2" >Parks & Recreation</td>
#                         <td id="T_a430cbfa_5614_11e9_b891_80ee73d5e3acrow6
